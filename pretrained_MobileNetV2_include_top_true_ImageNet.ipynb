# %% [markdown]
# ## **Import libraries**

# %%
import numpy as np # for calculation
import matplotlib.pyplot as plt # for plotting and viewing
import os # for loading images
from PIL import Image # for loading images

# %% [markdown]
# ## **Load images**

# %%
# define my image path
images_path = 'C:/Users/yangq/OneDrive/Desktop/computer vision/archive (1)/train'

# define lists to store image and label respectively
images = []
labels = []

# load our image
for folder_name in os.listdir(images_path):
    folder_path = os.path.join(images_path, folder_name)
    if os.path.isdir(folder_path):
        for filename in os.listdir(folder_path):
            image_path = os.path.join(folder_path, filename)
            img = Image.open(image_path)
            images.append(img)
            labels.append(folder_name)

# %% [markdown]
# ### (2.1) show the image

# %%
print(f"Label: {labels[7]}")
plt.imshow(images[7])
plt.axis("off")  # Turn off the axes
plt.title(f"Label: {labels[7]}")
plt.show()
# Out:
# Label: cats

# %% [markdown]
# ### (2.2) show image categories

# %%
unique_labels = set(labels)
print(f"Unique labels: {unique_labels}")
# Out:
# Unique labels: {'dogs', 'cats'}

# %% [markdown]
# ### (2.3) each number of image

# %%
from collections import Counter

label_counts = Counter(labels)
print("Label counts:")
for label, count in label_counts.items():
    print(f"{label}: {count} images")
# Out:
# Label counts:
# cats: 279 images
# dogs: 278 images

# %% [markdown]
# ## **Process dataset**

# %% [markdown]
# #### We obtain images and labels two lists, so if we want to use CNN models, we need to transfer them into the array respectively.

# %%
#  for our output
Y_1= np.array(labels)
Y_1
# Out:
# array(['cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats',
#        'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs',
#        'dogs', 'dogs', 'dogs', 'dogs', 'dogs'], dtype='<U4')

# %% [markdown]
# #### To transfer images list into an array, we need to check each image dimension first!

# %%
# check each image shape
for i, img in enumerate(images):
    print(f"Image {i} shape: {np.array(img).shape}")
# Out:
# Image 0 shape: (1333, 2000, 3)
# Image 1 shape: (183, 275, 3)
# Image 2 shape: (168, 300, 3)
# Image 3 shape: (628, 1200, 3)
# Image 4 shape: (162, 311, 3)
# Image 5 shape: (159, 318, 3)
# Image 6 shape: (549, 976, 3)
# Image 7 shape: (1200, 1200, 3)
# Image 8 shape: (176, 287, 3)
# Image 9 shape: (1414, 2121, 3)
# Image 10 shape: (2848, 4272, 3)
# Image 11 shape: (500, 1400, 3)
# Image 12 shape: (630, 1200, 3)
# Image 13 shape: (648, 1155, 3)
# Image 14 shape: (179, 282, 3)
# Image 15 shape: (637, 640, 3)
# Image 16 shape: (252, 400, 3)
# Image 17 shape: (1200, 1200, 3)
# Image 18 shape: (648, 1155, 3)
# Image 19 shape: (549, 976, 3)
# Image 20 shape: (667, 1000, 3)
# Image 21 shape: (1050, 1400, 3)
# Image 22 shape: (1329, 1920, 3)
# Image 23 shape: (720, 1280, 3)
# Image 24 shape: (2049, 3000, 3)
# Image 25 shape: (225, 225, 3)
# Image 26 shape: (600, 900, 3)
# Image 27 shape: (675, 1200, 3)
# Image 28 shape: (720, 1280, 3)
# Image 29 shape: (683, 1024, 3)
# Image 30 shape: (200, 350, 3)
# Image 31 shape: (626, 626, 3)
# Image 32 shape: (450, 800, 3)
# Image 33 shape: (182, 277, 3)
# Image 34 shape: (600, 1200, 3)
# Image 35 shape: (1200, 1200, 3)
# Image 36 shape: (134, 376, 3)
# Image 37 shape: (1062, 1600, 3)
# Image 38 shape: (499, 750, 3)
# Image 39 shape: (165, 306, 3)
# Image 40 shape: (200, 350, 3)
# Image 41 shape: (898, 1600, 3)
# Image 42 shape: (1066, 1600, 3)
# Image 43 shape: (136, 200, 3)
# Image 44 shape: (164, 307, 3)
# Image 45 shape: (298, 169, 3)
# Image 46 shape: (2000, 2000, 3)
# Image 47 shape: (409, 615, 3)
# Image 48 shape: (361, 344, 3)
# Image 49 shape: (640, 940, 3)
# Image 50 shape: (667, 1000, 3)
# Image 51 shape: (1000, 1500, 3)
# Image 52 shape: (600, 1160, 3)
# Image 53 shape: (179, 282, 3)
# Image 54 shape: (300, 750, 3)
# Image 55 shape: (183, 275, 3)
# Image 56 shape: (194, 259, 3)
# Image 57 shape: (300, 600, 3)
# Image 58 shape: (156, 322, 3)
# Image 59 shape: (1340, 1787, 3)
# Image 60 shape: (600, 1200, 3)
# Image 61 shape: (159, 318, 3)
# Image 62 shape: (698, 1240, 3)
# Image 63 shape: (350, 990, 3)
# Image 64 shape: (1193, 2121, 3)
# Image 65 shape: (393, 590, 3)
# Image 66 shape: (345, 615, 3)
# Image 67 shape: (432, 768, 3)
# Image 68 shape: (349, 525, 3)
# Image 69 shape: (576, 1024, 3)
# Image 70 shape: (600, 900, 3)
# Image 71 shape: (225, 225, 3)
# Image 72 shape: (1706, 1706, 3)
# Image 73 shape: (174, 290, 3)
# Image 74 shape: (429, 640, 3)
# Image 75 shape: (675, 900, 3)
# Image 76 shape: (585, 1040, 3)
# Image 77 shape: (183, 275, 3)
# Image 78 shape: (309, 549, 3)
# Image 79 shape: (675, 1200, 3)
# Image 80 shape: (183, 275, 3)
# Image 81 shape: (194, 259, 3)
# Image 82 shape: (1350, 2400, 3)
# Image 83 shape: (321, 480, 3)
# Image 84 shape: (512, 768, 3)
# Image 85 shape: (183, 276, 3)
# Image 86 shape: (982, 1071, 3)
# Image 87 shape: (1200, 1200, 3)
# Image 88 shape: (798, 1200, 3)
# Image 89 shape: (165, 306, 3)
# Image 90 shape: (1334, 2000, 3)
# Image 91 shape: (191, 264, 3)
# Image 92 shape: (383, 510, 3)
# Image 93 shape: (183, 275, 3)
# Image 94 shape: (499, 750, 3)
# Image 95 shape: (142, 355, 3)
# Image 96 shape: (1024, 1536, 3)
# Image 97 shape: (182, 276, 3)
# Image 98 shape: (642, 1000, 3)
# Image 99 shape: (184, 273, 3)
# Image 100 shape: (175, 287, 3)
# Image 101 shape: (185, 273, 3)
# Image 102 shape: (409, 615, 3)
# Image 103 shape: (400, 600, 3)
# Image 104 shape: (1045, 1568, 3)
# Image 105 shape: (1414, 2121, 3)
# Image 106 shape: (200, 300, 3)
# Image 107 shape: (340, 557, 3)
# Image 108 shape: (576, 1024, 3)
# Image 109 shape: (1000, 1500, 3)
# Image 110 shape: (533, 800, 3)
# Image 111 shape: (520, 964, 3)
# Image 112 shape: (1333, 1000, 3)
# Image 113 shape: (354, 630, 3)
# Image 114 shape: (703, 825, 3)
# Image 115 shape: (239, 211, 3)
# Image 116 shape: (600, 600, 3)
# Image 117 shape: (194, 259, 3)
# Image 118 shape: (1350, 2400, 3)
# Image 119 shape: (680, 680, 3)
# Image 120 shape: (394, 700, 3)
# Image 121 shape: (630, 1200, 3)
# Image 122 shape: (810, 1440, 3)
# Image 123 shape: (191, 264, 3)
# Image 124 shape: (225, 225, 3)
# Image 125 shape: (405, 720, 3)
# Image 126 shape: (460, 750, 3)
# Image 127 shape: (256, 197, 3)
# Image 128 shape: (1575, 2800, 3)
# Image 129 shape: (3024, 4032, 3)
# Image 130 shape: (422, 750, 3)
# Image 131 shape: (573, 1020, 3)
# Image 132 shape: (600, 1066, 3)
# Image 133 shape: (800, 800, 3)
# Image 134 shape: (620, 930, 3)
# Image 135 shape: (191, 685, 3)
# Image 136 shape: (225, 225, 3)
# Image 137 shape: (720, 1280, 3)
# Image 138 shape: (1067, 1600, 3)
# Image 139 shape: (1024, 1900, 3)
# Image 140 shape: (698, 1240, 3)
# Image 141 shape: (471, 700, 3)
# Image 142 shape: (800, 1200, 3)
# Image 143 shape: (164, 307, 3)
# Image 144 shape: (1400, 2100, 3)
# Image 145 shape: (1080, 1920, 3)
# Image 146 shape: (900, 1600, 3)
# Image 147 shape: (630, 1197, 3)
# Image 148 shape: (560, 1440, 3)
# Image 149 shape: (576, 1024, 3)
# Image 150 shape: (183, 275, 3)
# Image 151 shape: (225, 225, 3)
# Image 152 shape: (216, 389, 3)
# Image 153 shape: (183, 275, 3)
# Image 154 shape: (168, 300, 3)
# Image 155 shape: (224, 225, 3)
# Image 156 shape: (183, 275, 3)
# Image 157 shape: (211, 239, 3)
# Image 158 shape: (354, 500, 3)
# Image 159 shape: (225, 225, 3)
# Image 160 shape: (637, 640, 3)
# Image 161 shape: (205, 246, 3)
# Image 162 shape: (225, 225, 3)
# Image 163 shape: (300, 631, 3)
# Image 164 shape: (800, 1200, 3)
# Image 165 shape: (335, 335, 3)
# Image 166 shape: (2000, 3000, 3)
# Image 167 shape: (810, 1440, 3)
# Image 168 shape: (628, 1200, 3)
# Image 169 shape: (399, 600, 3)
# Image 170 shape: (936, 1500, 3)
# Image 171 shape: (931, 800, 3)
# Image 172 shape: (536, 1024, 3)
# Image 173 shape: (480, 640, 3)
# Image 174 shape: (233, 350, 3)
# Image 175 shape: (260, 194, 3)
# Image 176 shape: (512, 1024, 3)
# Image 177 shape: (400, 600, 3)
# Image 178 shape: (1067, 1600, 3)
# Image 179 shape: (225, 400, 3)
# Image 180 shape: (1000, 1500, 3)
# Image 181 shape: (183, 275, 3)
# Image 182 shape: (480, 1366, 3)
# Image 183 shape: (550, 728, 3)
# Image 184 shape: (1863, 2862, 3)
# Image 185 shape: (750, 900, 3)
# Image 186 shape: (183, 275, 3)
# Image 187 shape: (371, 660, 3)
# Image 188 shape: (1200, 1200, 3)
# Image 189 shape: (1998, 1332, 3)
# Image 190 shape: (1440, 2560, 3)
# Image 191 shape: (174, 290, 3)
# Image 192 shape: (409, 615, 3)
# Image 193 shape: (900, 1200, 3)
# Image 194 shape: (225, 225, 3)
# Image 195 shape: (423, 635, 3)
# Image 196 shape: (500, 500, 3)
# Image 197 shape: (183, 275, 3)
# Image 198 shape: (183, 275, 3)
# Image 199 shape: (925, 1541, 3)
# Image 200 shape: (420, 660, 3)
# Image 201 shape: (178, 283, 3)
# Image 202 shape: (250, 400, 3)
# Image 203 shape: (1080, 1620, 3)
# Image 204 shape: (1016, 2032, 3)
# Image 205 shape: (183, 275, 3)
# Image 206 shape: (630, 1200, 3)
# Image 207 shape: (514, 640, 3)
# Image 208 shape: (183, 275, 3)
# Image 209 shape: (560, 1440, 3)
# Image 210 shape: (183, 276, 3)
# Image 211 shape: (746, 1327, 3)
# Image 212 shape: (628, 1200, 3)
# Image 213 shape: (400, 750, 3)
# Image 214 shape: (675, 900, 3)
# Image 215 shape: (164, 307, 3)
# Image 216 shape: (1080, 1920, 3)
# Image 217 shape: (523, 500, 3)
# Image 218 shape: (1000, 1000, 3)
# Image 219 shape: (194, 259, 3)
# Image 220 shape: (550, 977, 3)
# Image 221 shape: (1200, 800, 3)
# Image 222 shape: (549, 976, 3)
# Image 223 shape: (4272, 3288, 3)
# Image 224 shape: (184, 274, 3)
# Image 225 shape: (174, 290, 3)
# Image 226 shape: (1435, 1600, 3)
# Image 227 shape: (133, 379, 3)
# Image 228 shape: (372, 660, 3)
# Image 229 shape: (900, 1200, 3)
# Image 230 shape: (200, 252, 3)
# Image 231 shape: (675, 1200, 3)
# Image 232 shape: (260, 260, 3)
# Image 233 shape: (400, 500, 3)
# Image 234 shape: (1214, 858, 3)
# Image 235 shape: (401, 600, 3)
# Image 236 shape: (720, 1280, 3)
# Image 237 shape: (900, 1200, 3)
# Image 238 shape: (1500, 1000, 3)
# Image 239 shape: (650, 976, 3)
# Image 240 shape: (183, 275, 3)
# Image 241 shape: (630, 1200, 3)
# Image 242 shape: (720, 1280, 3)
# Image 243 shape: (560, 1440, 3)
# Image 244 shape: (997, 2000, 3)
# Image 245 shape: (1200, 2400, 3)
# Image 246 shape: (590, 890, 3)
# Image 247 shape: (197, 256, 3)
# Image 248 shape: (1800, 1800, 3)
# Image 249 shape: (800, 1200, 3)
# Image 250 shape: (1200, 1200, 3)
# Image 251 shape: (400, 640, 3)
# Image 252 shape: (640, 1280, 3)
# Image 253 shape: (400, 400, 3)
# Image 254 shape: (1536, 1920, 3)
# Image 255 shape: (1801, 3200, 3)
# Image 256 shape: (253, 199, 3)
# Image 257 shape: (168, 299, 3)
# Image 258 shape: (168, 299, 3)
# Image 259 shape: (2000, 3000, 3)
# Image 260 shape: (1536, 3072, 3)
# Image 261 shape: (1602, 1200, 3)
# Image 262 shape: (330, 505, 3)
# Image 263 shape: (664, 1000, 3)
# Image 264 shape: (840, 1920, 3)
# Image 265 shape: (183, 275, 3)
# Image 266 shape: (1280, 1920, 3)
# Image 267 shape: (225, 225, 3)
# Image 268 shape: (427, 1024, 3)
# Image 269 shape: (1415, 2120, 3)
# Image 270 shape: (225, 225, 3)
# Image 271 shape: (3072, 2304, 3)
# Image 272 shape: (600, 1200, 3)
# Image 273 shape: (183, 275, 3)
# Image 274 shape: (562, 750, 3)
# Image 275 shape: (480, 1366, 3)
# Image 276 shape: (630, 1090, 3)
# Image 277 shape: (852, 1136, 3)
# Image 278 shape: (675, 1200, 3)
# Image 279 shape: (1067, 1600, 3)
# Image 280 shape: (1066, 1600, 3)
# Image 281 shape: (163, 310, 3)
# Image 282 shape: (205, 246, 3)
# Image 283 shape: (168, 299, 3)
# Image 284 shape: (720, 1280, 3)
# Image 285 shape: (183, 275, 3)
# Image 286 shape: (157, 322, 3)
# Image 287 shape: (133, 380, 3)
# Image 288 shape: (628, 1200, 3)
# Image 289 shape: (333, 500, 3)
# Image 290 shape: (183, 275, 3)
# Image 291 shape: (194, 259, 3)
# Image 292 shape: (900, 1200, 3)
# Image 293 shape: (1200, 1200, 3)
# Image 294 shape: (309, 550, 3)
# Image 295 shape: (1280, 1920, 3)
# Image 296 shape: (1800, 1800, 3)
# Image 297 shape: (722, 699, 3)
# Image 298 shape: (297, 170, 3)
# Image 299 shape: (1080, 1920, 3)
# Image 300 shape: (174, 290, 3)
# Image 301 shape: (250, 400, 3)
# Image 302 shape: (1500, 1000, 3)
# Image 303 shape: (520, 1200, 3)
# Image 304 shape: (1053, 1100, 3)
# Image 305 shape: (194, 259, 3)
# Image 306 shape: (223, 226, 3)
# Image 307 shape: (635, 640, 3)
# Image 308 shape: (1440, 1988, 3)
# Image 309 shape: (195, 258, 3)
# Image 310 shape: (2025, 3600, 3)
# Image 311 shape: (630, 1200, 3)
# Image 312 shape: (156, 324, 3)
# Image 313 shape: (640, 640, 3)
# Image 314 shape: (1050, 1400, 3)
# Image 315 shape: (340, 510, 3)
# Image 316 shape: (1819, 2405, 3)
# Image 317 shape: (212, 237, 3)
# Image 318 shape: (608, 1080, 3)
# Image 319 shape: (761, 1100, 3)
# Image 320 shape: (160, 315, 3)
# Image 321 shape: (183, 275, 3)
# Image 322 shape: (900, 1200, 3)
# Image 323 shape: (810, 1440, 3)
# Image 324 shape: (174, 290, 3)
# Image 325 shape: (712, 570, 3)
# Image 326 shape: (635, 640, 3)
# Image 327 shape: (1000, 2000, 3)
# Image 328 shape: (549, 976, 3)
# Image 329 shape: (1001, 1000, 3)
# Image 330 shape: (675, 1200, 3)
# Image 331 shape: (1070, 1500, 3)
# Image 332 shape: (638, 800, 3)
# Image 333 shape: (183, 275, 3)
# Image 334 shape: (601, 1000, 3)
# Image 335 shape: (164, 307, 3)
# Image 336 shape: (608, 1080, 3)
# Image 337 shape: (243, 207, 3)
# Image 338 shape: (820, 2560, 3)
# Image 339 shape: (208, 243, 3)
# Image 340 shape: (722, 921, 3)
# Image 341 shape: (396, 704, 3)
# Image 342 shape: (507, 760, 3)
# Image 343 shape: (194, 259, 3)
# Image 344 shape: (751, 1001, 3)
# Image 345 shape: (267, 400, 3)
# Image 346 shape: (183, 275, 3)
# Image 347 shape: (475, 632, 3)
# Image 348 shape: (600, 1024, 3)
# Image 349 shape: (158, 319, 3)
# Image 350 shape: (1864, 2800, 3)
# Image 351 shape: (181, 220, 3)
# Image 352 shape: (1228, 2880, 3)
# Image 353 shape: (576, 1024, 3)
# Image 354 shape: (938, 1500, 3)
# Image 355 shape: (183, 275, 3)
# Image 356 shape: (675, 1200, 3)
# Image 357 shape: (628, 1200, 3)
# Image 358 shape: (558, 630, 3)
# Image 359 shape: (884, 1920, 3)
# Image 360 shape: (999, 1500, 3)
# Image 361 shape: (233, 217, 3)
# Image 362 shape: (543, 724, 3)
# Image 363 shape: (460, 880, 3)
# Image 364 shape: (1125, 1500, 3)
# Image 365 shape: (208, 243, 3)
# Image 366 shape: (350, 400, 3)
# Image 367 shape: (1319, 2000, 3)
# Image 368 shape: (900, 1600, 3)
# Image 369 shape: (900, 1200, 3)
# Image 370 shape: (1354, 2215, 3)
# Image 371 shape: (207, 243, 3)
# Image 372 shape: (157, 321, 3)
# Image 373 shape: (410, 783, 3)
# Image 374 shape: (667, 1000, 3)
# Image 375 shape: (183, 275, 3)
# Image 376 shape: (183, 275, 3)
# Image 377 shape: (1024, 681, 3)
# Image 378 shape: (372, 660, 3)
# Image 379 shape: (191, 264, 3)
# Image 380 shape: (900, 1200, 3)
# Image 381 shape: (540, 960, 3)
# Image 382 shape: (250, 400, 3)
# Image 383 shape: (1536, 2048, 3)
# Image 384 shape: (303, 540, 3)
# Image 385 shape: (616, 1136, 3)
# Image 386 shape: (225, 400, 3)
# Image 387 shape: (500, 1040, 3)
# Image 388 shape: (500, 1040, 3)
# Image 389 shape: (183, 275, 3)
# Image 390 shape: (590, 800, 3)
# Image 391 shape: (2304, 3072, 3)
# Image 392 shape: (300, 400, 3)
# Image 393 shape: (700, 1050, 3)
# Image 394 shape: (1000, 1500, 3)
# Image 395 shape: (280, 574, 3)
# Image 396 shape: (225, 225, 3)
# Image 397 shape: (1057, 1600, 3)
# Image 398 shape: (667, 1000, 3)
# Image 399 shape: (400, 400, 3)
# Image 400 shape: (194, 260, 3)
# Image 401 shape: (168, 299, 3)
# Image 402 shape: (174, 290, 3)
# Image 403 shape: (182, 276, 3)
# Image 404 shape: (183, 275, 3)
# Image 405 shape: (1414, 2121, 3)
# Image 406 shape: (450, 845, 3)
# Image 407 shape: (168, 299, 3)
# Image 408 shape: (441, 784, 3)
# Image 409 shape: (1603, 2000, 3)
# Image 410 shape: (719, 760, 3)
# Image 411 shape: (259, 194, 3)
# Image 412 shape: (635, 640, 3)
# Image 413 shape: (1333, 2000, 3)
# Image 414 shape: (221, 228, 3)
# Image 415 shape: (1663, 2500, 3)
# Image 416 shape: (183, 275, 3)
# Image 417 shape: (445, 792, 3)
# Image 418 shape: (1000, 1500, 3)
# Image 419 shape: (409, 500, 3)
# Image 420 shape: (540, 810, 3)
# Image 421 shape: (800, 1528, 3)
# Image 422 shape: (408, 612, 3)
# Image 423 shape: (720, 1280, 3)
# Image 424 shape: (1440, 1920, 3)
# Image 425 shape: (309, 550, 3)
# Image 426 shape: (512, 512, 3)
# Image 427 shape: (1968, 3498, 3)
# Image 428 shape: (824, 1100, 3)
# Image 429 shape: (224, 225, 3)
# Image 430 shape: (810, 1080, 3)
# Image 431 shape: (194, 259, 3)
# Image 432 shape: (698, 1240, 3)
# Image 433 shape: (900, 1600, 3)
# Image 434 shape: (200, 133, 3)
# Image 435 shape: (979, 1304, 3)
# Image 436 shape: (1600, 1600, 3)
# Image 437 shape: (654, 980, 3)
# Image 438 shape: (1080, 1080, 3)
# Image 439 shape: (163, 308, 3)
# Image 440 shape: (372, 660, 3)
# Image 441 shape: (1080, 1920, 3)
# Image 442 shape: (600, 1065, 3)
# Image 443 shape: (432, 768, 3)
# Image 444 shape: (925, 1541, 3)
# Image 445 shape: (300, 400, 3)
# Image 446 shape: (520, 640, 3)
# Image 447 shape: (1200, 1200, 3)
# Image 448 shape: (1800, 1800, 3)
# Image 449 shape: (540, 960, 3)
# Image 450 shape: (194, 259, 3)
# Image 451 shape: (750, 1000, 3)
# Image 452 shape: (735, 490, 3)
# Image 453 shape: (549, 732, 3)
# Image 454 shape: (641, 640, 3)
# Image 455 shape: (1200, 1200, 3)
# Image 456 shape: (600, 1066, 3)
# Image 457 shape: (1000, 1000, 3)
# Image 458 shape: (183, 275, 3)
# Image 459 shape: (590, 800, 3)
# Image 460 shape: (1050, 1400, 3)
# Image 461 shape: (800, 1200, 3)
# Image 462 shape: (750, 1000, 3)
# Image 463 shape: (698, 1240, 3)
# Image 464 shape: (475, 632, 3)
# Image 465 shape: (622, 933, 3)
# Image 466 shape: (608, 1080, 3)
# Image 467 shape: (1500, 1000, 3)
# Image 468 shape: (180, 320, 3)
# Image 469 shape: (549, 976, 3)
# Image 470 shape: (533, 800, 3)
# Image 471 shape: (183, 275, 3)
# Image 472 shape: (183, 275, 3)
# Image 473 shape: (1000, 1500, 3)
# Image 474 shape: (536, 750, 3)
# Image 475 shape: (224, 225, 3)
# Image 476 shape: (641, 1920, 3)
# Image 477 shape: (155, 275, 3)
# Image 478 shape: (507, 760, 3)
# Image 479 shape: (182, 276, 3)
# Image 480 shape: (228, 800, 3)
# Image 481 shape: (675, 900, 3)
# Image 482 shape: (1200, 800, 3)
# Image 483 shape: (232, 218, 3)
# Image 484 shape: (716, 1272, 3)
# Image 485 shape: (225, 225, 3)
# Image 486 shape: (675, 1200, 3)
# Image 487 shape: (1800, 1800, 3)
# Image 488 shape: (300, 400, 3)
# Image 489 shape: (1000, 1500, 3)
# Image 490 shape: (506, 780, 3)
# Image 491 shape: (194, 259, 3)
# Image 492 shape: (426, 640)
# Image 493 shape: (207, 244, 3)
# Image 494 shape: (3161, 4169, 3)
# Image 495 shape: (549, 976, 3)
# Image 496 shape: (225, 225, 3)
# Image 497 shape: (900, 1200, 3)
# Image 498 shape: (430, 650, 3)
# Image 499 shape: (165, 305, 3)
# Image 500 shape: (183, 275, 3)
# Image 501 shape: (194, 259, 3)
# Image 502 shape: (225, 225, 3)
# Image 503 shape: (212, 237, 3)
# Image 504 shape: (600, 900, 3)
# Image 505 shape: (170, 297, 3)
# Image 506 shape: (835, 1255, 3)
# Image 507 shape: (1071, 1500, 3)
# Image 508 shape: (576, 1024, 3)
# Image 509 shape: (225, 225, 3)
# Image 510 shape: (168, 300, 3)
# Image 511 shape: (183, 275, 3)
# Image 512 shape: (545, 800, 3)
# Image 513 shape: (852, 1136, 3)
# Image 514 shape: (688, 1000, 3)
# Image 515 shape: (164, 307, 3)
# Image 516 shape: (175, 289, 3)
# Image 517 shape: (335, 640, 3)
# Image 518 shape: (480, 480, 3)
# Image 519 shape: (675, 1200, 3)
# Image 520 shape: (320, 480, 3)
# Image 521 shape: (1350, 2400, 3)
# Image 522 shape: (507, 900, 3)
# Image 523 shape: (435, 590, 3)
# Image 524 shape: (1500, 3000, 3)
# Image 525 shape: (372, 660, 3)
# Image 526 shape: (260, 260, 3)
# Image 527 shape: (750, 1125, 3)
# Image 528 shape: (1728, 3072, 3)
# Image 529 shape: (600, 800, 3)
# Image 530 shape: (658, 1170, 3)
# Image 531 shape: (168, 300, 3)
# Image 532 shape: (2283, 3425, 3)
# Image 533 shape: (2063, 1920, 3)
# Image 534 shape: (500, 1040, 3)
# Image 535 shape: (1000, 1000, 3)
# Image 536 shape: (876, 1200, 3)
# Image 537 shape: (892, 1440, 3)
# Image 538 shape: (200, 350, 3)
# Image 539 shape: (191, 264, 3)
# Image 540 shape: (1725, 2560, 3)
# Image 541 shape: (507, 760, 3)
# Image 542 shape: (194, 259, 3)
# Image 543 shape: (218, 232, 3)
# Image 544 shape: (1080, 1920, 3)
# Image 545 shape: (638, 640, 3)
# Image 546 shape: (1001, 1500, 3)
# Image 547 shape: (1461, 2000, 3)
# Image 548 shape: (1080, 1920, 3)
# Image 549 shape: (183, 275, 3)
# Image 550 shape: (650, 899, 3)
# Image 551 shape: (4096, 2765, 3)
# Image 552 shape: (756, 1200, 3)
# Image 553 shape: (3072, 2304, 3)
# Image 554 shape: (221, 228, 3)
# Image 555 shape: (750, 1000, 3)
# Image 556 shape: (183, 275, 3)

# %% [markdown]
# #### So we need to rehape each image, the each new image has the same dimension.

# %%
# define output image size
output_size = (224, 224)  # (Height, Width)

# reshape all images to the target size
resized_images = []
for i, img in enumerate(images):
    # Ensure all images are in RGB format (3 channels)
    img = img.convert("RGB")  # Convert to RGB
    img_resized = img.resize(output_size)  # Resize the image
    img_array = np.array(img_resized)  # Convert to NumPy array
    resized_images.append(img_array) # add new image into the array

# %% [markdown]
# ### (3.2) convert it into an np.array

# %%
# Convert the resized images list to a single NumPy array
image_array = np.array(resized_images)
print("Final array shape:", image_array.shape)
# Out:
# Final array shape: (557, 224, 224, 3)

# %% [markdown]
# ## **MobileNetV2**

# %% [markdown]
# ## There are some limits of using the pre-trained MobileNetV2 model

# %% [markdown]
# ### (1) The input image deminision must be (224, 224, 3)

# %% [markdown]
# ### (2) Your images must be in 1000 classes (ImageNet dataset categories)

# %% [markdown]
# ### Because we use ImageNet dataset to pre-train the model, so we do not need to use our images to train the model

# %% [markdown]
# ### (4.1) Import the model

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2

# %%
pretrained_model = MobileNetV2(include_top = True, weights = 'imagenet')
pretrained_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer_10[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 112, 112,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 112, 112,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 112, 112,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 112, 112,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 113, 113,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 56, 56,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 56, 56,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 56, 56,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 56, 56,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 56, 56,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 56, 56,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 56, 56,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 56, 56,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 56, 56,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 56, 56,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 56, 56,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 56, 56,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 56, 56,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 57, 57,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 28, 28,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 28, 28,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 28, 28,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 28, 28,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 28, 28,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 28, 28,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 28, 28,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 28, 28,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 28, 28,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 28, 28,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 28, 28,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 28, 28,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 28, 28,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 28, 28,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 28, 28,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 28, 28,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 28, 28,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 28, 28,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 28, 28,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 28, 28,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 29, 29,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 14, 14,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 14, 14,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 14, 14,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 14, 14,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 14, 14,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 14, 14,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 14, 14,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 14, 14,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 14, 14,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 14, 14,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 14, 14,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 14, 14,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 14, 14,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 14, 14,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 14, 14,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 14, 14,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 14, 14,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 14, 14,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 14, 14,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 14, 14,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 14, 14,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 14, 14,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 14, 14,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 14, 14,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 14, 14,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 14, 14,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 14, 14,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 14, 14,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 14, 14,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 14, 14,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 14, 14,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 14, 14,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 14, 14,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 14, 14,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 14, 14,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 14, 14,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 14, 14,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 14, 14,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 14, 14,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 14, 14,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 14, 14,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 14, 14,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 14, 14,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 14, 14,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 14, 14,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 14, 14,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 14, 14,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 15, 15,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 7, 7, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 7, 7, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 7, 7, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 7, 7, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 7, 7, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 7, 7, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 7, 7, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 7, 7, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 7, 7, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 7, 7, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 7, 7, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 7, 7, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 7, 7, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 7, 7, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 7, 7, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 7, 7, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 7, 7, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 7, 7,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 7, 7,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 7, 7,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 1000)      │  1,281,000 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,538,984 (13.50 MB)
#  Trainable params: 3,504,872 (13.37 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %% [markdown]
# ### (4.2) Normalize images

# %% [markdown]
# ### Most pre-trained models require pixel values to be normalized. For MobileNetV2, use the preprocess_input function:

# %%
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# Preprocess the images
image_array1 = preprocess_input(image_array)  # Normalize to range [-1, 1]
image_array1.shape
# Out:
# (557, 224, 224, 3)

# %%
resized_images1 = tf.image.resize(image_array1, (224, 224))
resized_images1.shape
# Out:
# TensorShape([557, 224, 224, 3])

# %% [markdown]
# ### (4.3) Make Predictions

# %%
predictions = pretrained_model.predict(image_array1)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step

# %% [markdown]
# ## (4.4) Decode the result

# %% [markdown]
# ### Use decode_prediction to decode the result

# %% [markdown]
# #### We need to resize the nparray to the tensor, so that we can use decode function.

# %%
from tensorflow.keras.applications.mobilenet_v2 import decode_predictions

# Decode top 5 predictions for each image
decoded_predictions = decode_predictions(predictions, top=5)
for i, preds in enumerate(decoded_predictions):
    print(f"Image {i+1}:")
    for rank, (class_id, label, prob) in enumerate(preds):
        print(f"  {rank+1}: {label} ({prob:.2f})")
# Out:
# Image 1:
#   1: tabby (0.57)
#   2: tiger_cat (0.31)
#   3: Egyptian_cat (0.03)
#   4: tiger (0.01)
#   5: lynx (0.01)
# Image 2:
#   1: Egyptian_cat (0.29)
#   2: lynx (0.11)
#   3: Persian_cat (0.10)
#   4: tabby (0.06)
#   5: tiger_cat (0.02)
# Image 3:
#   1: Egyptian_cat (0.71)
#   2: tabby (0.07)
#   3: Siamese_cat (0.06)
#   4: Persian_cat (0.03)
#   5: tiger_cat (0.01)
# Image 4:
#   1: Persian_cat (0.61)
#   2: lynx (0.14)
#   3: Egyptian_cat (0.11)
#   4: tabby (0.02)
#   5: tiger_cat (0.01)
# Image 5:
#   1: Egyptian_cat (0.65)
#   2: tabby (0.07)
#   3: lynx (0.02)
#   4: Siamese_cat (0.02)
#   5: tiger_cat (0.01)
# Image 6:
#   1: tabby (0.27)
#   2: tiger_cat (0.11)
#   3: lynx (0.07)
#   4: Egyptian_cat (0.03)
#   5: Persian_cat (0.03)
# Image 7:
#   1: sunglasses (0.14)
#   2: sunglass (0.10)
#   3: Siamese_cat (0.08)
#   4: Egyptian_cat (0.07)
#   5: llama (0.06)
# Image 8:
#   1: Persian_cat (0.45)
#   2: tiger_cat (0.11)
#   3: tabby (0.05)
#   4: doormat (0.03)
#   5: jean (0.02)
# Image 9:
#   1: fox_squirrel (0.09)
#   2: grey_fox (0.05)
#   3: wood_rabbit (0.02)
#   4: honeycomb (0.02)
#   5: kit_fox (0.02)
# Image 10:
#   1: Persian_cat (0.60)
#   2: lynx (0.17)
#   3: Pomeranian (0.03)
#   4: Arctic_fox (0.02)
#   5: Maltese_dog (0.01)
# Image 11:
#   1: tiger_cat (0.24)
#   2: Egyptian_cat (0.19)
#   3: tabby (0.11)
#   4: Siamese_cat (0.04)
#   5: toy_terrier (0.02)
# Image 12:
#   1: tabby (0.25)
#   2: Egyptian_cat (0.23)
#   3: lynx (0.12)
#   4: tiger_cat (0.05)
#   5: Persian_cat (0.04)
# Image 13:
#   1: Egyptian_cat (0.68)
#   2: quilt (0.01)
#   3: Siamese_cat (0.01)
#   4: sleeping_bag (0.01)
#   5: stole (0.01)
# Image 14:
#   1: toy_terrier (0.69)
#   2: sleeping_bag (0.06)
#   3: papillon (0.02)
#   4: Siamese_cat (0.01)
#   5: Egyptian_cat (0.01)
# Image 15:
#   1: Siamese_cat (0.83)
#   2: Egyptian_cat (0.01)
#   3: tabby (0.01)
#   4: Persian_cat (0.01)
#   5: tiger_cat (0.01)
# Image 16:
#   1: lynx (0.36)
#   2: Persian_cat (0.17)
#   3: tiger_cat (0.05)
#   4: quilt (0.03)
#   5: Egyptian_cat (0.02)
# Image 17:
#   1: Egyptian_cat (0.68)
#   2: tabby (0.11)
#   3: lynx (0.03)
#   4: tiger_cat (0.03)
#   5: triceratops (0.00)
# Image 18:
#   1: tiger_cat (0.48)
#   2: tabby (0.25)
#   3: Egyptian_cat (0.04)
#   4: Persian_cat (0.02)
#   5: window_screen (0.01)
# Image 19:
#   1: tabby (0.25)
#   2: tiger_cat (0.16)
#   3: Egyptian_cat (0.10)
#   4: lynx (0.02)
#   5: jaguar (0.02)
# Image 20:
#   1: tiger_cat (0.44)
#   2: tabby (0.24)
#   3: Egyptian_cat (0.12)
#   4: lynx (0.03)
#   5: tiger (0.00)
# Image 21:
#   1: Egyptian_cat (0.57)
#   2: tiger_cat (0.12)
#   3: lynx (0.03)
#   4: tabby (0.02)
#   5: bath_towel (0.02)
# Image 22:
#   1: Egyptian_cat (0.15)
#   2: tiger (0.13)
#   3: tiger_cat (0.11)
#   4: tabby (0.06)
#   5: lynx (0.04)
# Image 23:
#   1: tabby (0.51)
#   2: tiger_cat (0.23)
#   3: Egyptian_cat (0.14)
#   4: lynx (0.00)
#   5: fox_squirrel (0.00)
# Image 24:
#   1: tabby (0.60)
#   2: tiger_cat (0.25)
#   3: Egyptian_cat (0.06)
#   4: tiger (0.01)
#   5: lynx (0.01)
# Image 25:
#   1: Persian_cat (0.36)
#   2: Siamese_cat (0.10)
#   3: tabby (0.02)
#   4: feather_boa (0.01)
#   5: refrigerator (0.01)
# Image 26:
#   1: tabby (0.71)
#   2: Egyptian_cat (0.13)
#   3: tiger_cat (0.06)
#   4: Persian_cat (0.01)
#   5: lynx (0.00)
# Image 27:
#   1: Persian_cat (0.44)
#   2: lynx (0.26)
#   3: Siamese_cat (0.09)
#   4: tabby (0.03)
#   5: tiger_cat (0.02)
# Image 28:
#   1: Egyptian_cat (0.46)
#   2: tabby (0.25)
#   3: tiger_cat (0.13)
#   4: lynx (0.02)
#   5: ping-pong_ball (0.01)
# Image 29:
#   1: Egyptian_cat (0.39)
#   2: tabby (0.29)
#   3: lynx (0.05)
#   4: Persian_cat (0.03)
#   5: tiger_cat (0.03)
# Image 30:
#   1: Egyptian_cat (0.35)
#   2: Persian_cat (0.11)
#   3: tabby (0.05)
#   4: pug (0.05)
#   5: French_bulldog (0.05)
# Image 31:
#   1: tiger_cat (0.38)
#   2: Egyptian_cat (0.34)
#   3: tabby (0.13)
#   4: Siamese_cat (0.01)
#   5: black-footed_ferret (0.01)
# Image 32:
#   1: rubber_eraser (0.12)
#   2: envelope (0.06)
#   3: comic_book (0.05)
#   4: Band_Aid (0.05)
#   5: coffee_mug (0.04)
# Image 33:
#   1: tabby (0.49)
#   2: tiger_cat (0.38)
#   3: lynx (0.03)
#   4: Egyptian_cat (0.01)
#   5: radiator (0.00)
# Image 34:
#   1: Egyptian_cat (0.51)
#   2: tiger_cat (0.21)
#   3: tabby (0.20)
#   4: lynx (0.02)
#   5: Siamese_cat (0.00)
# Image 35:
#   1: Egyptian_cat (0.33)
#   2: tabby (0.25)
#   3: tiger_cat (0.25)
#   4: lynx (0.03)
#   5: washbasin (0.00)
# Image 36:
#   1: tabby (0.47)
#   2: Egyptian_cat (0.46)
#   3: tiger_cat (0.02)
#   4: lynx (0.00)
#   5: lens_cap (0.00)
# Image 37:
#   1: toy_terrier (0.41)
#   2: Walker_hound (0.12)
#   3: Italian_greyhound (0.07)
#   4: basenji (0.05)
#   5: English_foxhound (0.03)
# Image 38:
#   1: washbasin (0.19)
#   2: Persian_cat (0.10)
#   3: tub (0.07)
#   4: Angora (0.05)
#   5: bathtub (0.04)
# Image 39:
#   1: carton (0.57)
#   2: Egyptian_cat (0.08)
#   3: tiger_cat (0.05)
#   4: tabby (0.03)
#   5: tub (0.02)
# Image 40:
#   1: dogsled (0.51)
#   2: hair_slide (0.05)
#   3: borzoi (0.04)
#   4: Eskimo_dog (0.02)
#   5: Arctic_fox (0.02)
# Image 41:
#   1: Egyptian_cat (0.47)
#   2: tabby (0.16)
#   3: tiger_cat (0.16)
#   4: Persian_cat (0.01)
#   5: feather_boa (0.01)
# Image 42:
#   1: Persian_cat (0.43)
#   2: tabby (0.15)
#   3: tiger_cat (0.05)
#   4: laptop (0.04)
#   5: Pomeranian (0.04)
# Image 43:
#   1: Persian_cat (0.20)
#   2: Egyptian_cat (0.07)
#   3: tiger_cat (0.03)
#   4: tabby (0.02)
#   5: Siamese_cat (0.01)
# Image 44:
#   1: tabby (0.84)
#   2: tiger_cat (0.06)
#   3: Egyptian_cat (0.03)
#   4: lynx (0.01)
#   5: Persian_cat (0.00)
# Image 45:
#   1: coffee_mug (0.35)
#   2: thimble (0.15)
#   3: milk_can (0.08)
#   4: coffeepot (0.07)
#   5: cup (0.05)
# Image 46:
#   1: tabby (0.80)
#   2: Egyptian_cat (0.10)
#   3: Persian_cat (0.02)
#   4: tiger_cat (0.02)
#   5: lynx (0.00)
# Image 47:
#   1: comic_book (0.38)
#   2: hook (0.10)
#   3: joystick (0.03)
#   4: chime (0.03)
#   5: revolver (0.02)
# Image 48:
#   1: lynx (0.24)
#   2: Egyptian_cat (0.12)
#   3: Persian_cat (0.11)
#   4: tiger_cat (0.04)
#   5: tabby (0.04)
# Image 49:
#   1: Egyptian_cat (0.79)
#   2: tiger_cat (0.01)
#   3: Siamese_cat (0.01)
#   4: lesser_panda (0.01)
#   5: Border_collie (0.01)
# Image 50:
#   1: tabby (0.51)
#   2: Persian_cat (0.25)
#   3: lynx (0.08)
#   4: tiger_cat (0.05)
#   5: Egyptian_cat (0.02)
# Image 51:
#   1: Persian_cat (0.65)
#   2: lynx (0.03)
#   3: Egyptian_cat (0.01)
#   4: plastic_bag (0.01)
#   5: lab_coat (0.01)
# Image 52:
#   1: tabby (0.58)
#   2: tiger_cat (0.22)
#   3: hamper (0.01)
#   4: Egyptian_cat (0.01)
#   5: radiator (0.01)
# Image 53:
#   1: lynx (0.75)
#   2: tiger_cat (0.04)
#   3: Persian_cat (0.02)
#   4: tabby (0.01)
#   5: great_grey_owl (0.01)
# Image 54:
#   1: tabby (0.72)
#   2: Egyptian_cat (0.12)
#   3: tiger_cat (0.09)
#   4: lynx (0.00)
#   5: triceratops (0.00)
# Image 55:
#   1: Egyptian_cat (0.54)
#   2: tabby (0.06)
#   3: tiger_cat (0.02)
#   4: lynx (0.01)
#   5: Siamese_cat (0.01)
# Image 56:
#   1: Indian_cobra (0.19)
#   2: fur_coat (0.09)
#   3: horned_viper (0.02)
#   4: fox_squirrel (0.02)
#   5: sunglass (0.01)
# Image 57:
#   1: tabby (0.70)
#   2: Egyptian_cat (0.21)
#   3: tiger_cat (0.04)
#   4: lynx (0.01)
#   5: Persian_cat (0.00)
# Image 58:
#   1: Egyptian_cat (0.26)
#   2: tabby (0.13)
#   3: lynx (0.10)
#   4: tiger_cat (0.07)
#   5: washbasin (0.02)
# Image 59:
#   1: Egyptian_cat (0.38)
#   2: lynx (0.23)
#   3: tabby (0.22)
#   4: tiger_cat (0.06)
#   5: Siamese_cat (0.01)
# Image 60:
#   1: tiger_cat (0.28)
#   2: Egyptian_cat (0.26)
#   3: tabby (0.12)
#   4: shower_curtain (0.04)
#   5: window_screen (0.03)
# Image 61:
#   1: tiger_cat (0.62)
#   2: tabby (0.19)
#   3: Egyptian_cat (0.08)
#   4: lynx (0.01)
#   5: mixing_bowl (0.00)
# Image 62:
#   1: Egyptian_cat (0.42)
#   2: lynx (0.35)
#   3: cougar (0.05)
#   4: kit_fox (0.04)
#   5: grey_fox (0.02)
# Image 63:
#   1: Persian_cat (0.41)
#   2: Angora (0.03)
#   3: plastic_bag (0.02)
#   4: lynx (0.02)
#   5: tabby (0.01)
# Image 64:
#   1: tabby (0.18)
#   2: lynx (0.08)
#   3: Egyptian_cat (0.05)
#   4: tiger_cat (0.04)
#   5: Siamese_cat (0.03)
# Image 65:
#   1: paper_towel (0.16)
#   2: hamper (0.10)
#   3: tiger_cat (0.06)
#   4: Siamese_cat (0.04)
#   5: Egyptian_cat (0.03)
# Image 66:
#   1: Egyptian_cat (0.70)
#   2: tabby (0.16)
#   3: tiger_cat (0.04)
#   4: drumstick (0.02)
#   5: dumbbell (0.01)
# Image 67:
#   1: tiger_cat (0.58)
#   2: tabby (0.14)
#   3: Egyptian_cat (0.07)
#   4: tiger (0.04)
#   5: lynx (0.01)
# Image 68:
#   1: Egyptian_cat (0.65)
#   2: tabby (0.09)
#   3: tiger_cat (0.08)
#   4: lynx (0.02)
#   5: Siamese_cat (0.01)
# Image 69:
#   1: Persian_cat (0.36)
#   2: marmoset (0.11)
#   3: Pekinese (0.10)
#   4: Angora (0.03)
#   5: Siamese_cat (0.03)
# Image 70:
#   1: lynx (0.35)
#   2: Egyptian_cat (0.23)
#   3: tabby (0.08)
#   4: snow_leopard (0.03)
#   5: tiger_cat (0.03)
# Image 71:
#   1: Egyptian_cat (0.44)
#   2: tiger_cat (0.10)
#   3: tabby (0.07)
#   4: Siamese_cat (0.05)
#   5: Brittany_spaniel (0.01)
# Image 72:
#   1: plastic_bag (0.11)
#   2: Persian_cat (0.08)
#   3: hamper (0.07)
#   4: tabby (0.05)
#   5: feather_boa (0.04)
# Image 73:
#   1: macaque (0.04)
#   2: Pomeranian (0.04)
#   3: Norwich_terrier (0.03)
#   4: lynx (0.02)
#   5: marmoset (0.01)
# Image 74:
#   1: switch (0.38)
#   2: spotlight (0.04)
#   3: hook (0.03)
#   4: mousetrap (0.03)
#   5: thresher (0.03)
# Image 75:
#   1: Egyptian_cat (0.08)
#   2: horned_viper (0.05)
#   3: mousetrap (0.04)
#   4: night_snake (0.04)
#   5: hermit_crab (0.03)
# Image 76:
#   1: tabby (0.33)
#   2: tiger_cat (0.24)
#   3: Egyptian_cat (0.23)
#   4: lynx (0.01)
#   5: Siamese_cat (0.00)
# Image 77:
#   1: tabby (0.53)
#   2: tiger_cat (0.27)
#   3: Egyptian_cat (0.06)
#   4: tiger (0.02)
#   5: lynx (0.01)
# Image 78:
#   1: Egyptian_cat (0.63)
#   2: tabby (0.17)
#   3: tiger_cat (0.08)
#   4: lynx (0.01)
#   5: desktop_computer (0.00)
# Image 79:
#   1: lynx (0.94)
#   2: tiger_cat (0.02)
#   3: tabby (0.01)
#   4: Egyptian_cat (0.00)
#   5: Persian_cat (0.00)
# Image 80:
#   1: Egyptian_cat (0.51)
#   2: lynx (0.19)
#   3: tiger_cat (0.03)
#   4: tabby (0.02)
#   5: cairn (0.01)
# Image 81:
#   1: ruffed_grouse (0.28)
#   2: partridge (0.15)
#   3: quail (0.06)
#   4: black_grouse (0.04)
#   5: lynx (0.03)
# Image 82:
#   1: tabby (0.23)
#   2: Egyptian_cat (0.12)
#   3: tiger_cat (0.10)
#   4: space_heater (0.02)
#   5: hamper (0.02)
# Image 83:
#   1: sleeping_bag (0.22)
#   2: Egyptian_cat (0.20)
#   3: Siamese_cat (0.14)
#   4: tabby (0.09)
#   5: tiger_cat (0.07)
# Image 84:
#   1: Persian_cat (0.94)
#   2: Angora (0.00)
#   3: Japanese_spaniel (0.00)
#   4: corkscrew (0.00)
#   5: Pomeranian (0.00)
# Image 85:
#   1: marmot (0.43)
#   2: wombat (0.06)
#   3: cairn (0.03)
#   4: marmoset (0.02)
#   5: badger (0.02)
# Image 86:
#   1: Egyptian_cat (0.51)
#   2: Siamese_cat (0.09)
#   3: tabby (0.06)
#   4: tiger_cat (0.02)
#   5: stethoscope (0.02)
# Image 87:
#   1: Persian_cat (0.71)
#   2: lynx (0.06)
#   3: tabby (0.04)
#   4: Egyptian_cat (0.01)
#   5: tiger_cat (0.01)
# Image 88:
#   1: Siamese_cat (0.87)
#   2: Egyptian_cat (0.02)
#   3: tabby (0.01)
#   4: lynx (0.01)
#   5: tiger_cat (0.00)
# Image 89:
#   1: Egyptian_cat (0.11)
#   2: tabby (0.08)
#   3: schipperke (0.07)
#   4: Persian_cat (0.07)
#   5: groenendael (0.04)
# Image 90:
#   1: Egyptian_cat (0.54)
#   2: Siamese_cat (0.02)
#   3: dingo (0.02)
#   4: lynx (0.02)
#   5: tiger_cat (0.02)
# Image 91:
#   1: tabby (0.30)
#   2: Egyptian_cat (0.27)
#   3: tiger_cat (0.25)
#   4: lynx (0.01)
#   5: space_heater (0.00)
# Image 92:
#   1: Egyptian_cat (0.35)
#   2: tabby (0.30)
#   3: tiger_cat (0.08)
#   4: lynx (0.03)
#   5: Persian_cat (0.01)
# Image 93:
#   1: Egyptian_cat (0.67)
#   2: tiger_cat (0.09)
#   3: tabby (0.07)
#   4: lynx (0.02)
#   5: Siamese_cat (0.00)
# Image 94:
#   1: Egyptian_cat (0.49)
#   2: tabby (0.23)
#   3: tiger_cat (0.16)
#   4: lynx (0.01)
#   5: Persian_cat (0.00)
# Image 95:
#   1: Egyptian_cat (0.35)
#   2: tabby (0.10)
#   3: tiger_cat (0.06)
#   4: Siamese_cat (0.04)
#   5: paper_towel (0.02)
# Image 96:
#   1: Egyptian_cat (0.22)
#   2: tabby (0.03)
#   3: three-toed_sloth (0.03)
#   4: weasel (0.02)
#   5: tiger_cat (0.02)
# Image 97:
#   1: Egyptian_cat (0.15)
#   2: Pembroke (0.11)
#   3: Shetland_sheepdog (0.09)
#   4: collie (0.08)
#   5: Siberian_husky (0.05)
# Image 98:
#   1: Old_English_sheepdog (0.12)
#   2: borzoi (0.11)
#   3: Sealyham_terrier (0.06)
#   4: Japanese_spaniel (0.05)
#   5: Angora (0.04)
# Image 99:
#   1: Egyptian_cat (0.35)
#   2: tiger_cat (0.21)
#   3: tabby (0.20)
#   4: lynx (0.07)
#   5: grey_fox (0.00)
# Image 100:
#   1: Egyptian_cat (0.63)
#   2: tiger_cat (0.21)
#   3: tabby (0.08)
#   4: lynx (0.02)
#   5: tiger (0.00)
# Image 101:
#   1: Egyptian_cat (0.42)
#   2: tiger_cat (0.18)
#   3: tabby (0.14)
#   4: lynx (0.06)
#   5: Siamese_cat (0.02)
# Image 102:
#   1: tabby (0.65)
#   2: Egyptian_cat (0.13)
#   3: tiger_cat (0.06)
#   4: lynx (0.01)
#   5: Persian_cat (0.01)
# Image 103:
#   1: Persian_cat (0.12)
#   2: guinea_pig (0.09)
#   3: tiger_cat (0.07)
#   4: hamster (0.06)
#   5: carton (0.04)
# Image 104:
#   1: tiger_cat (0.69)
#   2: Egyptian_cat (0.10)
#   3: tabby (0.08)
#   4: lynx (0.02)
#   5: wok (0.00)
# Image 105:
#   1: tabby (0.27)
#   2: Egyptian_cat (0.11)
#   3: lynx (0.07)
#   4: Siamese_cat (0.05)
#   5: tiger_cat (0.04)
# Image 106:
#   1: Egyptian_cat (0.46)
#   2: tabby (0.16)
#   3: tiger_cat (0.11)
#   4: sleeping_bag (0.01)
#   5: lynx (0.01)
# Image 107:
#   1: tiger_cat (0.33)
#   2: tabby (0.21)
#   3: Egyptian_cat (0.15)
#   4: lynx (0.03)
#   5: Persian_cat (0.03)
# Image 108:
#   1: Egyptian_cat (0.36)
#   2: tiger_cat (0.31)
#   3: tabby (0.11)
#   4: lynx (0.03)
#   5: Madagascar_cat (0.02)
# Image 109:
#   1: tiger_cat (0.50)
#   2: tabby (0.15)
#   3: Egyptian_cat (0.09)
#   4: mixing_bowl (0.03)
#   5: cup (0.03)
# Image 110:
#   1: skunk (0.14)
#   2: papillon (0.10)
#   3: Yorkshire_terrier (0.03)
#   4: Chihuahua (0.01)
#   5: Persian_cat (0.01)
# Image 111:
#   1: lynx (0.77)
#   2: Siamese_cat (0.10)
#   3: Persian_cat (0.03)
#   4: Egyptian_cat (0.02)
#   5: tabby (0.02)
# Image 112:
#   1: Egyptian_cat (0.17)
#   2: grey_fox (0.05)
#   3: dingo (0.04)
#   4: red_wolf (0.04)
#   5: cougar (0.03)
# Image 113:
#   1: tiger_cat (0.84)
#   2: tabby (0.06)
#   3: lynx (0.04)
#   4: Egyptian_cat (0.02)
#   5: lion (0.00)
# Image 114:
#   1: tiger_cat (0.51)
#   2: tabby (0.31)
#   3: Egyptian_cat (0.04)
#   4: lynx (0.01)
#   5: radiator (0.00)
# Image 115:
#   1: Egyptian_cat (0.76)
#   2: lynx (0.04)
#   3: grey_fox (0.02)
#   4: Siamese_cat (0.01)
#   5: cougar (0.01)
# Image 116:
#   1: Persian_cat (0.73)
#   2: lynx (0.08)
#   3: Siamese_cat (0.03)
#   4: Egyptian_cat (0.02)
#   5: tabby (0.01)
# Image 117:
#   1: Egyptian_cat (0.28)
#   2: tabby (0.26)
#   3: tiger_cat (0.22)
#   4: carton (0.05)
#   5: ping-pong_ball (0.01)
# Image 118:
#   1: cowboy_boot (0.13)
#   2: mask (0.09)
#   3: ski_mask (0.08)
#   4: Cardigan (0.05)
#   5: kelpie (0.03)
# Image 119:
#   1: Egyptian_cat (0.35)
#   2: Eskimo_dog (0.13)
#   3: Siberian_husky (0.08)
#   4: tabby (0.03)
#   5: Siamese_cat (0.03)
# Image 120:
#   1: tabby (0.51)
#   2: Egyptian_cat (0.18)
#   3: tiger_cat (0.13)
#   4: washbasin (0.01)
#   5: carton (0.01)
# Image 121:
#   1: Egyptian_cat (0.40)
#   2: tabby (0.05)
#   3: Siamese_cat (0.02)
#   4: slot (0.02)
#   5: toyshop (0.02)
# Image 122:
#   1: Egyptian_cat (0.82)
#   2: tabby (0.05)
#   3: lynx (0.02)
#   4: grey_fox (0.01)
#   5: kit_fox (0.01)
# Image 123:
#   1: tabby (0.48)
#   2: Egyptian_cat (0.21)
#   3: tiger_cat (0.14)
#   4: lynx (0.03)
#   5: remote_control (0.01)
# Image 124:
#   1: tabby (0.72)
#   2: Egyptian_cat (0.11)
#   3: tiger_cat (0.10)
#   4: lynx (0.01)
#   5: paper_towel (0.00)
# Image 125:
#   1: tabby (0.58)
#   2: Egyptian_cat (0.16)
#   3: Persian_cat (0.04)
#   4: tiger_cat (0.04)
#   5: cougar (0.01)
# Image 126:
#   1: Egyptian_cat (0.23)
#   2: Persian_cat (0.13)
#   3: tiger_cat (0.10)
#   4: lynx (0.04)
#   5: tabby (0.03)
# Image 127:
#   1: Egyptian_cat (0.49)
#   2: grey_fox (0.07)
#   3: lynx (0.05)
#   4: hyena (0.04)
#   5: tiger_cat (0.03)
# Image 128:
#   1: web_site (0.86)
#   2: screen (0.02)
#   3: envelope (0.01)
#   4: rule (0.01)
#   5: menu (0.01)
# Image 129:
#   1: tabby (0.56)
#   2: tiger_cat (0.22)
#   3: Egyptian_cat (0.02)
#   4: lynx (0.01)
#   5: wood_rabbit (0.00)
# Image 130:
#   1: tabby (0.76)
#   2: Egyptian_cat (0.06)
#   3: tiger_cat (0.06)
#   4: carton (0.00)
#   5: lynx (0.00)
# Image 131:
#   1: Persian_cat (0.57)
#   2: tiger_cat (0.03)
#   3: Angora (0.02)
#   4: tabby (0.01)
#   5: bath_towel (0.01)
# Image 132:
#   1: lynx (0.42)
#   2: tiger_cat (0.40)
#   3: tabby (0.02)
#   4: Egyptian_cat (0.02)
#   5: Persian_cat (0.01)
# Image 133:
#   1: tiger_cat (0.43)
#   2: tabby (0.22)
#   3: Egyptian_cat (0.19)
#   4: academic_gown (0.01)
#   5: sleeping_bag (0.01)
# Image 134:
#   1: Egyptian_cat (0.32)
#   2: tabby (0.08)
#   3: pedestal (0.04)
#   4: cowboy_boot (0.03)
#   5: shower_cap (0.03)
# Image 135:
#   1: Siamese_cat (0.97)
#   2: Egyptian_cat (0.00)
#   3: Persian_cat (0.00)
#   4: weasel (0.00)
#   5: lynx (0.00)
# Image 136:
#   1: hog (0.57)
#   2: kelpie (0.03)
#   3: worm_fence (0.01)
#   4: badger (0.01)
#   5: wild_boar (0.01)
# Image 137:
#   1: safety_pin (0.14)
#   2: hair_slide (0.09)
#   3: rubber_eraser (0.06)
#   4: nipple (0.04)
#   5: Band_Aid (0.03)
# Image 138:
#   1: Persian_cat (0.38)
#   2: tabby (0.22)
#   3: Egyptian_cat (0.04)
#   4: tiger_cat (0.03)
#   5: lynx (0.03)
# Image 139:
#   1: tiger_cat (0.47)
#   2: tabby (0.41)
#   3: Egyptian_cat (0.09)
#   4: lynx (0.00)
#   5: spotlight (0.00)
# Image 140:
#   1: dogsled (0.38)
#   2: Eskimo_dog (0.08)
#   3: Cardigan (0.05)
#   4: Arctic_fox (0.03)
#   5: Siberian_husky (0.03)
# Image 141:
#   1: hamster (0.06)
#   2: guinea_pig (0.05)
#   3: nipple (0.04)
#   4: ping-pong_ball (0.04)
#   5: Siamese_cat (0.04)
# Image 142:
#   1: tiger_cat (0.61)
#   2: Persian_cat (0.11)
#   3: tabby (0.03)
#   4: Egyptian_cat (0.02)
#   5: computer_keyboard (0.02)
# Image 143:
#   1: tiger_cat (0.52)
#   2: Egyptian_cat (0.24)
#   3: tabby (0.08)
#   4: lynx (0.04)
#   5: bath_towel (0.01)
# Image 144:
#   1: wall_clock (0.17)
#   2: analog_clock (0.12)
#   3: ocarina (0.12)
#   4: toyshop (0.05)
#   5: jack-o'-lantern (0.03)
# Image 145:
#   1: Egyptian_cat (0.13)
#   2: Border_collie (0.07)
#   3: collie (0.06)
#   4: Eskimo_dog (0.05)
#   5: malamute (0.04)
# Image 146:
#   1: Persian_cat (0.69)
#   2: lynx (0.12)
#   3: tiger_cat (0.02)
#   4: tabby (0.01)
#   5: Siamese_cat (0.01)
# Image 147:
#   1: tiger_cat (0.57)
#   2: tabby (0.32)
#   3: Egyptian_cat (0.02)
#   4: sock (0.00)
#   5: lynx (0.00)
# Image 148:
#   1: tiger_cat (0.32)
#   2: bath_towel (0.27)
#   3: tabby (0.04)
#   4: Egyptian_cat (0.03)
#   5: dishrag (0.02)
# Image 149:
#   1: Egyptian_cat (0.50)
#   2: tabby (0.18)
#   3: tiger_cat (0.05)
#   4: lynx (0.02)
#   5: shower_curtain (0.02)
# Image 150:
#   1: tiger_cat (0.56)
#   2: tabby (0.07)
#   3: Norwich_terrier (0.04)
#   4: Yorkshire_terrier (0.03)
#   5: Egyptian_cat (0.02)
# Image 151:
#   1: Egyptian_cat (0.77)
#   2: tabby (0.04)
#   3: Siamese_cat (0.03)
#   4: tiger_cat (0.03)
#   5: lynx (0.02)
# Image 152:
#   1: tiger_cat (0.11)
#   2: Egyptian_cat (0.10)
#   3: tabby (0.09)
#   4: lynx (0.06)
#   5: fox_squirrel (0.04)
# Image 153:
#   1: tabby (0.41)
#   2: Egyptian_cat (0.09)
#   3: tiger_cat (0.07)
#   4: lynx (0.07)
#   5: Siamese_cat (0.01)
# Image 154:
#   1: tabby (0.68)
#   2: Egyptian_cat (0.20)
#   3: tiger_cat (0.05)
#   4: lynx (0.02)
#   5: Siamese_cat (0.00)
# Image 155:
#   1: Persian_cat (0.54)
#   2: lynx (0.05)
#   3: tabby (0.03)
#   4: Siamese_cat (0.03)
#   5: Egyptian_cat (0.03)
# Image 156:
#   1: tiger_cat (0.35)
#   2: Egyptian_cat (0.30)
#   3: tabby (0.19)
#   4: lynx (0.03)
#   5: plastic_bag (0.01)
# Image 157:
#   1: lynx (0.48)
#   2: Egyptian_cat (0.21)
#   3: tabby (0.06)
#   4: tiger_cat (0.04)
#   5: leopard (0.01)
# Image 158:
#   1: tabby (0.90)
#   2: tiger_cat (0.04)
#   3: Egyptian_cat (0.03)
#   4: lynx (0.00)
#   5: refrigerator (0.00)
# Image 159:
#   1: tabby (0.44)
#   2: tiger_cat (0.33)
#   3: Egyptian_cat (0.02)
#   4: lynx (0.02)
#   5: Persian_cat (0.01)
# Image 160:
#   1: face_powder (0.34)
#   2: plate_rack (0.03)
#   3: spotlight (0.03)
#   4: disk_brake (0.03)
#   5: lampshade (0.02)
# Image 161:
#   1: Egyptian_cat (0.90)
#   2: Siamese_cat (0.03)
#   3: tabby (0.01)
#   4: lynx (0.01)
#   5: tiger_cat (0.00)
# Image 162:
#   1: Siamese_cat (0.10)
#   2: cougar (0.08)
#   3: Brabancon_griffon (0.07)
#   4: red_wolf (0.04)
#   5: Egyptian_cat (0.04)
# Image 163:
#   1: Egyptian_cat (0.30)
#   2: Siamese_cat (0.09)
#   3: mink (0.02)
#   4: pot (0.02)
#   5: hamper (0.02)
# Image 164:
#   1: Siamese_cat (0.17)
#   2: Angora (0.08)
#   3: papillon (0.04)
#   4: Egyptian_cat (0.04)
#   5: skunk (0.02)
# Image 165:
#   1: Egyptian_cat (0.26)
#   2: tabby (0.18)
#   3: tiger_cat (0.09)
#   4: lynx (0.03)
#   5: space_heater (0.03)
# Image 166:
#   1: tabby (0.33)
#   2: sleeping_bag (0.10)
#   3: tiger_cat (0.08)
#   4: Egyptian_cat (0.08)
#   5: shower_curtain (0.03)
# Image 167:
#   1: Egyptian_cat (0.22)
#   2: tabby (0.20)
#   3: dining_table (0.10)
#   4: tiger_cat (0.07)
#   5: Persian_cat (0.03)
# Image 168:
#   1: lynx (0.67)
#   2: grey_fox (0.05)
#   3: fox_squirrel (0.04)
#   4: snow_leopard (0.01)
#   5: tiger_cat (0.01)
# Image 169:
#   1: Egyptian_cat (0.15)
#   2: Siamese_cat (0.15)
#   3: Persian_cat (0.12)
#   4: lynx (0.06)
#   5: tabby (0.03)
# Image 170:
#   1: Egyptian_cat (0.27)
#   2: hamper (0.19)
#   3: bonnet (0.13)
#   4: Siamese_cat (0.03)
#   5: hamster (0.02)
# Image 171:
#   1: tiger_cat (0.43)
#   2: Egyptian_cat (0.26)
#   3: lynx (0.08)
#   4: tabby (0.05)
#   5: Siamese_cat (0.01)
# Image 172:
#   1: tabby (0.68)
#   2: tiger_cat (0.16)
#   3: lynx (0.04)
#   4: Egyptian_cat (0.02)
#   5: Persian_cat (0.00)
# Image 173:
#   1: Egyptian_cat (0.47)
#   2: tiger_cat (0.17)
#   3: tabby (0.06)
#   4: lynx (0.05)
#   5: grey_fox (0.00)
# Image 174:
#   1: cheetah (0.37)
#   2: leopard (0.21)
#   3: snow_leopard (0.05)
#   4: Egyptian_cat (0.02)
#   5: Indian_cobra (0.02)
# Image 175:
#   1: Egyptian_cat (0.77)
#   2: tiger_cat (0.04)
#   3: tabby (0.03)
#   4: carton (0.02)
#   5: Siamese_cat (0.01)
# Image 176:
#   1: Siamese_cat (0.16)
#   2: Egyptian_cat (0.12)
#   3: Cardigan (0.06)
#   4: papillon (0.04)
#   5: Pembroke (0.03)
# Image 177:
#   1: Egyptian_cat (0.33)
#   2: lynx (0.18)
#   3: Siamese_cat (0.11)
#   4: cougar (0.05)
#   5: swab (0.05)
# Image 178:
#   1: thimble (0.43)
#   2: cup (0.03)
#   3: tabby (0.03)
#   4: mixing_bowl (0.03)
#   5: Egyptian_cat (0.03)
# Image 179:
#   1: Egyptian_cat (0.24)
#   2: Siamese_cat (0.16)
#   3: papillon (0.02)
#   4: Pembroke (0.02)
#   5: llama (0.01)
# Image 180:
#   1: tabby (0.25)
#   2: Egyptian_cat (0.04)
#   3: ibex (0.02)
#   4: hammer (0.02)
#   5: barbell (0.02)
# Image 181:
#   1: Egyptian_cat (0.48)
#   2: tabby (0.14)
#   3: tiger_cat (0.09)
#   4: Siamese_cat (0.07)
#   5: Persian_cat (0.01)
# Image 182:
#   1: Egyptian_cat (0.49)
#   2: tabby (0.32)
#   3: lynx (0.06)
#   4: tiger_cat (0.04)
#   5: Persian_cat (0.03)
# Image 183:
#   1: tabby (0.38)
#   2: Egyptian_cat (0.28)
#   3: tiger_cat (0.20)
#   4: notebook (0.02)
#   5: remote_control (0.01)
# Image 184:
#   1: collie (0.61)
#   2: Shetland_sheepdog (0.09)
#   3: Persian_cat (0.03)
#   4: papillon (0.02)
#   5: Border_collie (0.02)
# Image 185:
#   1: Egyptian_cat (0.72)
#   2: Siamese_cat (0.02)
#   3: mink (0.01)
#   4: weasel (0.01)
#   5: tiger_cat (0.01)
# Image 186:
#   1: washbasin (0.23)
#   2: tub (0.11)
#   3: cup (0.10)
#   4: bucket (0.10)
#   5: mixing_bowl (0.08)
# Image 187:
#   1: tabby (0.37)
#   2: Egyptian_cat (0.34)
#   3: tiger_cat (0.12)
#   4: lynx (0.01)
#   5: grey_fox (0.01)
# Image 188:
#   1: Angora (0.28)
#   2: hamster (0.18)
#   3: Egyptian_cat (0.06)
#   4: Persian_cat (0.04)
#   5: Siamese_cat (0.04)
# Image 189:
#   1: Persian_cat (0.83)
#   2: Angora (0.05)
#   3: Pomeranian (0.02)
#   4: Siamese_cat (0.01)
#   5: Pekinese (0.00)
# Image 190:
#   1: Siamese_cat (0.07)
#   2: ladle (0.05)
#   3: letter_opener (0.04)
#   4: rocking_chair (0.04)
#   5: lynx (0.03)
# Image 191:
#   1: lynx (0.46)
#   2: Persian_cat (0.25)
#   3: tiger_cat (0.06)
#   4: tabby (0.02)
#   5: patas (0.00)
# Image 192:
#   1: Egyptian_cat (0.74)
#   2: tabby (0.18)
#   3: tiger_cat (0.03)
#   4: lynx (0.00)
#   5: Siamese_cat (0.00)
# Image 193:
#   1: Egyptian_cat (0.38)
#   2: jaguar (0.17)
#   3: tiger_cat (0.06)
#   4: pajama (0.03)
#   5: leopard (0.03)
# Image 194:
#   1: tiger_cat (0.38)
#   2: tabby (0.37)
#   3: lynx (0.05)
#   4: Persian_cat (0.04)
#   5: Egyptian_cat (0.03)
# Image 195:
#   1: Egyptian_cat (0.71)
#   2: tabby (0.06)
#   3: lynx (0.05)
#   4: tiger_cat (0.02)
#   5: snow_leopard (0.00)
# Image 196:
#   1: Irish_terrier (0.07)
#   2: Pembroke (0.06)
#   3: Norwich_terrier (0.04)
#   4: Egyptian_cat (0.04)
#   5: vizsla (0.03)
# Image 197:
#   1: lynx (0.31)
#   2: tiger_cat (0.19)
#   3: Egyptian_cat (0.17)
#   4: tabby (0.10)
#   5: Siamese_cat (0.01)
# Image 198:
#   1: Egyptian_cat (0.33)
#   2: tabby (0.22)
#   3: tiger_cat (0.19)
#   4: lynx (0.05)
#   5: Persian_cat (0.03)
# Image 199:
#   1: Siamese_cat (0.42)
#   2: Persian_cat (0.33)
#   3: tabby (0.01)
#   4: Egyptian_cat (0.01)
#   5: face_powder (0.01)
# Image 200:
#   1: tiger_cat (0.24)
#   2: Egyptian_cat (0.17)
#   3: lynx (0.14)
#   4: tiger (0.05)
#   5: cougar (0.04)
# Image 201:
#   1: tabby (0.62)
#   2: Egyptian_cat (0.17)
#   3: tiger_cat (0.15)
#   4: lynx (0.00)
#   5: platypus (0.00)
# Image 202:
#   1: Egyptian_cat (0.61)
#   2: tabby (0.14)
#   3: lynx (0.04)
#   4: tiger_cat (0.03)
#   5: cheetah (0.00)
# Image 203:
#   1: Persian_cat (0.30)
#   2: lynx (0.18)
#   3: tabby (0.07)
#   4: Egyptian_cat (0.07)
#   5: tiger_cat (0.05)
# Image 204:
#   1: washbasin (0.12)
#   2: Persian_cat (0.10)
#   3: lynx (0.04)
#   4: plastic_bag (0.04)
#   5: paper_towel (0.03)
# Image 205:
#   1: goblet (0.17)
#   2: water_jug (0.15)
#   3: Egyptian_cat (0.07)
#   4: mouse (0.07)
#   5: tabby (0.05)
# Image 206:
#   1: tabby (0.71)
#   2: Egyptian_cat (0.20)
#   3: tiger_cat (0.04)
#   4: lynx (0.00)
#   5: snow_leopard (0.00)
# Image 207:
#   1: tabby (0.36)
#   2: Egyptian_cat (0.32)
#   3: tiger_cat (0.19)
#   4: lynx (0.03)
#   5: washbasin (0.01)
# Image 208:
#   1: Siamese_cat (0.38)
#   2: Egyptian_cat (0.12)
#   3: tabby (0.04)
#   4: lynx (0.02)
#   5: carton (0.02)
# Image 209:
#   1: Egyptian_cat (0.71)
#   2: tiger_cat (0.03)
#   3: lynx (0.03)
#   4: tabby (0.01)
#   5: Persian_cat (0.01)
# Image 210:
#   1: Egyptian_cat (0.57)
#   2: tiger_cat (0.19)
#   3: tabby (0.15)
#   4: lynx (0.03)
#   5: window_screen (0.00)
# Image 211:
#   1: tabby (0.55)
#   2: tiger_cat (0.18)
#   3: Egyptian_cat (0.17)
#   4: lynx (0.00)
#   5: remote_control (0.00)
# Image 212:
#   1: Egyptian_cat (0.44)
#   2: Siamese_cat (0.14)
#   3: tabby (0.03)
#   4: lynx (0.02)
#   5: tiger_cat (0.01)
# Image 213:
#   1: Egyptian_cat (0.23)
#   2: tabby (0.08)
#   3: quilt (0.06)
#   4: hamper (0.03)
#   5: velvet (0.03)
# Image 214:
#   1: bath_towel (0.50)
#   2: Siamese_cat (0.20)
#   3: tabby (0.07)
#   4: sleeping_bag (0.03)
#   5: Persian_cat (0.03)
# Image 215:
#   1: tabby (0.33)
#   2: Persian_cat (0.08)
#   3: tiger_cat (0.07)
#   4: lynx (0.05)
#   5: Egyptian_cat (0.03)
# Image 216:
#   1: goose (0.38)
#   2: ibex (0.08)
#   3: prairie_chicken (0.06)
#   4: impala (0.05)
#   5: hartebeest (0.04)
# Image 217:
#   1: cougar (0.60)
#   2: lynx (0.11)
#   3: Egyptian_cat (0.06)
#   4: jaguar (0.01)
#   5: wallaby (0.01)
# Image 218:
#   1: Egyptian_cat (0.31)
#   2: tabby (0.18)
#   3: lynx (0.17)
#   4: tiger_cat (0.04)
#   5: Persian_cat (0.02)
# Image 219:
#   1: tiger_cat (0.38)
#   2: tabby (0.14)
#   3: lynx (0.14)
#   4: Persian_cat (0.08)
#   5: Egyptian_cat (0.08)
# Image 220:
#   1: Persian_cat (0.71)
#   2: Angora (0.03)
#   3: marmoset (0.02)
#   4: chow (0.01)
#   5: Maltese_dog (0.01)
# Image 221:
#   1: Egyptian_cat (0.33)
#   2: tabby (0.29)
#   3: tiger_cat (0.16)
#   4: lynx (0.09)
#   5: remote_control (0.01)
# Image 222:
#   1: tiger_cat (0.41)
#   2: tabby (0.33)
#   3: Persian_cat (0.15)
#   4: Egyptian_cat (0.04)
#   5: otter (0.00)
# Image 223:
#   1: tabby (0.60)
#   2: Egyptian_cat (0.28)
#   3: tiger_cat (0.09)
#   4: lynx (0.01)
#   5: wood_rabbit (0.00)
# Image 224:
#   1: tabby (0.52)
#   2: lynx (0.11)
#   3: tiger_cat (0.10)
#   4: Egyptian_cat (0.03)
#   5: Persian_cat (0.02)
# Image 225:
#   1: Boston_bull (0.29)
#   2: Egyptian_cat (0.14)
#   3: Cardigan (0.08)
#   4: Siamese_cat (0.07)
#   5: papillon (0.05)
# Image 226:
#   1: flat-coated_retriever (0.06)
#   2: schipperke (0.05)
#   3: groenendael (0.04)
#   4: Border_collie (0.04)
#   5: Brabancon_griffon (0.03)
# Image 227:
#   1: mink (0.11)
#   2: groenendael (0.11)
#   3: cougar (0.09)
#   4: American_black_bear (0.08)
#   5: Egyptian_cat (0.06)
# Image 228:
#   1: wood_rabbit (0.75)
#   2: tabby (0.10)
#   3: hare (0.03)
#   4: tiger_cat (0.02)
#   5: fox_squirrel (0.01)
# Image 229:
#   1: Egyptian_cat (0.49)
#   2: lynx (0.09)
#   3: tabby (0.08)
#   4: tiger_cat (0.04)
#   5: Siamese_cat (0.01)
# Image 230:
#   1: tabby (0.62)
#   2: Egyptian_cat (0.25)
#   3: tiger_cat (0.04)
#   4: lynx (0.01)
#   5: Persian_cat (0.00)
# Image 231:
#   1: tabby (0.45)
#   2: tiger_cat (0.11)
#   3: Persian_cat (0.09)
#   4: lynx (0.09)
#   5: Egyptian_cat (0.08)
# Image 232:
#   1: Egyptian_cat (0.43)
#   2: carton (0.10)
#   3: mouse (0.05)
#   4: Siamese_cat (0.04)
#   5: toaster (0.02)
# Image 233:
#   1: Egyptian_cat (0.30)
#   2: Siamese_cat (0.18)
#   3: Persian_cat (0.08)
#   4: tabby (0.06)
#   5: tiger_cat (0.02)
# Image 234:
#   1: Egyptian_cat (0.70)
#   2: tabby (0.15)
#   3: tiger_cat (0.08)
#   4: lynx (0.01)
#   5: leopard (0.00)
# Image 235:
#   1: web_site (0.55)
#   2: menu (0.22)
#   3: window_shade (0.01)
#   4: crossword_puzzle (0.01)
#   5: whistle (0.00)
# Image 236:
#   1: Shih-Tzu (0.30)
#   2: Blenheim_spaniel (0.03)
#   3: Lhasa (0.03)
#   4: Siamese_cat (0.03)
#   5: Pekinese (0.02)
# Image 237:
#   1: Egyptian_cat (0.31)
#   2: tabby (0.10)
#   3: Persian_cat (0.09)
#   4: teddy (0.03)
#   5: tiger_cat (0.02)
# Image 238:
#   1: tiger_cat (0.49)
#   2: Egyptian_cat (0.16)
#   3: tabby (0.15)
#   4: tiger (0.01)
#   5: lynx (0.01)
# Image 239:
#   1: Egyptian_cat (0.39)
#   2: tabby (0.24)
#   3: tiger_cat (0.09)
#   4: lynx (0.02)
#   5: Persian_cat (0.02)
# Image 240:
#   1: tabby (0.55)
#   2: tiger_cat (0.25)
#   3: Egyptian_cat (0.11)
#   4: remote_control (0.01)
#   5: wood_rabbit (0.00)
# Image 241:
#   1: Siamese_cat (0.59)
#   2: Egyptian_cat (0.19)
#   3: cougar (0.03)
#   4: tabby (0.02)
#   5: tiger_cat (0.02)
# Image 242:
#   1: lynx (0.44)
#   2: Egyptian_cat (0.12)
#   3: tabby (0.08)
#   4: tiger_cat (0.07)
#   5: Persian_cat (0.04)
# Image 243:
#   1: lynx (0.31)
#   2: plastic_bag (0.11)
#   3: washbasin (0.07)
#   4: tabby (0.06)
#   5: shower_curtain (0.05)
# Image 244:
#   1: Egyptian_cat (0.13)
#   2: tiger_cat (0.07)
#   3: tabby (0.05)
#   4: hare (0.04)
#   5: lynx (0.03)
# Image 245:
#   1: Siamese_cat (0.89)
#   2: lynx (0.01)
#   3: Egyptian_cat (0.01)
#   4: tabby (0.01)
#   5: Persian_cat (0.01)
# Image 246:
#   1: Egyptian_cat (0.49)
#   2: tabby (0.16)
#   3: tiger_cat (0.09)
#   4: lynx (0.03)
#   5: Norwegian_elkhound (0.02)
# Image 247:
#   1: Egyptian_cat (0.53)
#   2: tabby (0.32)
#   3: tiger_cat (0.06)
#   4: lynx (0.01)
#   5: remote_control (0.00)
# Image 248:
#   1: Norwegian_elkhound (0.66)
#   2: wombat (0.04)
#   3: red_wolf (0.02)
#   4: keeshond (0.02)
#   5: grey_fox (0.01)
# Image 249:
#   1: tiger_cat (0.61)
#   2: tabby (0.13)
#   3: Egyptian_cat (0.06)
#   4: lynx (0.02)
#   5: tiger (0.01)
# Image 250:
#   1: Egyptian_cat (0.22)
#   2: Siamese_cat (0.04)
#   3: paper_towel (0.04)
#   4: tabby (0.04)
#   5: carton (0.02)
# Image 251:
#   1: tabby (0.41)
#   2: tiger_cat (0.34)
#   3: Egyptian_cat (0.11)
#   4: lynx (0.01)
#   5: Persian_cat (0.00)
# Image 252:
#   1: Band_Aid (0.21)
#   2: jigsaw_puzzle (0.17)
#   3: envelope (0.03)
#   4: rubber_eraser (0.02)
#   5: eft (0.02)
# Image 253:
#   1: maillot (0.29)
#   2: torch (0.15)
#   3: maillot (0.13)
#   4: comic_book (0.06)
#   5: bikini (0.05)
# Image 254:
#   1: refrigerator (0.27)
#   2: tiger_cat (0.21)
#   3: Egyptian_cat (0.09)
#   4: tabby (0.08)
#   5: window_screen (0.06)
# Image 255:
#   1: tabby (0.47)
#   2: tiger_cat (0.33)
#   3: Egyptian_cat (0.08)
#   4: lynx (0.01)
#   5: washbasin (0.00)
# Image 256:
#   1: tiger_cat (0.90)
#   2: tabby (0.05)
#   3: Egyptian_cat (0.01)
#   4: lynx (0.00)
#   5: window_screen (0.00)
# Image 257:
#   1: Persian_cat (0.48)
#   2: Pekinese (0.09)
#   3: Pomeranian (0.05)
#   4: otter (0.03)
#   5: sea_lion (0.02)
# Image 258:
#   1: Egyptian_cat (0.83)
#   2: Siamese_cat (0.07)
#   3: tabby (0.02)
#   4: schipperke (0.01)
#   5: tiger_cat (0.00)
# Image 259:
#   1: tabby (0.64)
#   2: tiger_cat (0.17)
#   3: Egyptian_cat (0.11)
#   4: window_screen (0.01)
#   5: lynx (0.00)
# Image 260:
#   1: fur_coat (0.30)
#   2: koala (0.03)
#   3: Shetland_sheepdog (0.03)
#   4: conch (0.02)
#   5: bubble (0.02)
# Image 261:
#   1: Egyptian_cat (0.84)
#   2: tiger_cat (0.05)
#   3: lynx (0.03)
#   4: tabby (0.02)
#   5: Siamese_cat (0.01)
# Image 262:
#   1: tiger_cat (0.47)
#   2: tabby (0.19)
#   3: Egyptian_cat (0.09)
#   4: lynx (0.01)
#   5: doormat (0.00)
# Image 263:
#   1: Egyptian_cat (0.46)
#   2: tabby (0.19)
#   3: tiger_cat (0.11)
#   4: lynx (0.11)
#   5: shower_curtain (0.00)
# Image 264:
#   1: Cardigan (0.15)
#   2: bath_towel (0.12)
#   3: bassinet (0.11)
#   4: Boston_bull (0.09)
#   5: cradle (0.06)
# Image 265:
#   1: tiger_cat (0.49)
#   2: tabby (0.41)
#   3: tiger (0.02)
#   4: lynx (0.02)
#   5: Egyptian_cat (0.01)
# Image 266:
#   1: tabby (0.66)
#   2: tiger_cat (0.22)
#   3: Egyptian_cat (0.06)
#   4: doormat (0.01)
#   5: lynx (0.01)
# Image 267:
#   1: Cardigan (0.37)
#   2: tiger_cat (0.08)
#   3: basenji (0.07)
#   4: tiger (0.05)
#   5: Egyptian_cat (0.04)
# Image 268:
#   1: tabby (0.60)
#   2: Egyptian_cat (0.26)
#   3: Persian_cat (0.02)
#   4: lynx (0.01)
#   5: tiger_cat (0.01)
# Image 269:
#   1: lynx (0.21)
#   2: Egyptian_cat (0.18)
#   3: remote_control (0.03)
#   4: tabby (0.02)
#   5: rule (0.02)
# Image 270:
#   1: Egyptian_cat (0.17)
#   2: tiger_cat (0.17)
#   3: tabby (0.13)
#   4: carton (0.02)
#   5: scale (0.02)
# Image 271:
#   1: Siamese_cat (0.84)
#   2: Egyptian_cat (0.07)
#   3: tabby (0.02)
#   4: lynx (0.01)
#   5: tiger_cat (0.00)
# Image 272:
#   1: Egyptian_cat (0.47)
#   2: lynx (0.20)
#   3: tabby (0.13)
#   4: Siamese_cat (0.03)
#   5: tiger_cat (0.02)
# Image 273:
#   1: Egyptian_cat (0.22)
#   2: tiger_cat (0.17)
#   3: lynx (0.13)
#   4: tabby (0.10)
#   5: Siamese_cat (0.03)
# Image 274:
#   1: Egyptian_cat (0.58)
#   2: tabby (0.05)
#   3: Siamese_cat (0.03)
#   4: fox_squirrel (0.03)
#   5: tiger_cat (0.01)
# Image 275:
#   1: Egyptian_cat (0.23)
#   2: Persian_cat (0.19)
#   3: tabby (0.19)
#   4: tiger_cat (0.07)
#   5: Siamese_cat (0.05)
# Image 276:
#   1: wood_rabbit (0.38)
#   2: tabby (0.36)
#   3: tiger_cat (0.09)
#   4: Egyptian_cat (0.03)
#   5: hare (0.02)
# Image 277:
#   1: tiger_cat (0.24)
#   2: Egyptian_cat (0.21)
#   3: tabby (0.15)
#   4: Persian_cat (0.07)
#   5: lynx (0.04)
# Image 278:
#   1: Egyptian_cat (0.39)
#   2: tiger_cat (0.32)
#   3: tabby (0.16)
#   4: lynx (0.02)
#   5: window_screen (0.00)
# Image 279:
#   1: lynx (0.22)
#   2: Egyptian_cat (0.20)
#   3: Siamese_cat (0.15)
#   4: Persian_cat (0.03)
#   5: washbasin (0.03)
# Image 280:
#   1: Welsh_springer_spaniel (0.18)
#   2: collie (0.16)
#   3: Pembroke (0.09)
#   4: Border_collie (0.07)
#   5: Cardigan (0.04)
# Image 281:
#   1: malinois (0.33)
#   2: whippet (0.09)
#   3: German_shepherd (0.04)
#   4: Ibizan_hound (0.04)
#   5: Mexican_hairless (0.04)
# Image 282:
#   1: West_Highland_white_terrier (0.39)
#   2: Scotch_terrier (0.12)
#   3: Lakeland_terrier (0.09)
#   4: Dandie_Dinmont (0.06)
#   5: wire-haired_fox_terrier (0.04)
# Image 283:
#   1: bull_mastiff (0.18)
#   2: pug (0.12)
#   3: bloodhound (0.06)
#   4: tiger (0.05)
#   5: Brabancon_griffon (0.03)
# Image 284:
#   1: Staffordshire_bullterrier (0.48)
#   2: bull_mastiff (0.18)
#   3: American_Staffordshire_terrier (0.16)
#   4: Great_Dane (0.02)
#   5: Mexican_hairless (0.02)
# Image 285:
#   1: whippet (0.25)
#   2: English_foxhound (0.17)
#   3: dalmatian (0.10)
#   4: dogsled (0.06)
#   5: Ibizan_hound (0.04)
# Image 286:
#   1: Samoyed (0.69)
#   2: Arctic_fox (0.06)
#   3: borzoi (0.03)
#   4: Great_Pyrenees (0.01)
#   5: wallaby (0.01)
# Image 287:
#   1: kuvasz (0.22)
#   2: Bedlington_terrier (0.11)
#   3: standard_poodle (0.06)
#   4: English_setter (0.04)
#   5: clumber (0.04)
# Image 288:
#   1: toy_terrier (0.41)
#   2: English_foxhound (0.09)
#   3: Walker_hound (0.05)
#   4: muzzle (0.03)
#   5: boxer (0.03)
# Image 289:
#   1: boxer (0.45)
#   2: bull_mastiff (0.05)
#   3: American_Staffordshire_terrier (0.04)
#   4: pug (0.03)
#   5: beagle (0.03)
# Image 290:
#   1: Rhodesian_ridgeback (0.46)
#   2: redbone (0.45)
#   3: black-and-tan_coonhound (0.04)
#   4: Walker_hound (0.01)
#   5: Labrador_retriever (0.00)
# Image 291:
#   1: collie (0.74)
#   2: Shetland_sheepdog (0.19)
#   3: Border_collie (0.01)
#   4: papillon (0.00)
#   5: borzoi (0.00)
# Image 292:
#   1: English_setter (0.15)
#   2: German_short-haired_pointer (0.14)
#   3: bluetick (0.13)
#   4: dalmatian (0.07)
#   5: miniature_poodle (0.03)
# Image 293:
#   1: pug (0.78)
#   2: Brabancon_griffon (0.04)
#   3: Pekinese (0.01)
#   4: bull_mastiff (0.01)
#   5: French_bulldog (0.00)
# Image 294:
#   1: flat-coated_retriever (0.87)
#   2: Labrador_retriever (0.01)
#   3: curly-coated_retriever (0.01)
#   4: German_short-haired_pointer (0.01)
#   5: Weimaraner (0.01)
# Image 295:
#   1: American_Staffordshire_terrier (0.31)
#   2: bull_mastiff (0.08)
#   3: boxer (0.06)
#   4: Labrador_retriever (0.03)
#   5: whippet (0.03)
# Image 296:
#   1: collie (0.82)
#   2: Shetland_sheepdog (0.06)
#   3: briard (0.01)
#   4: Australian_terrier (0.01)
#   5: Pomeranian (0.01)
# Image 297:
#   1: golden_retriever (0.91)
#   2: cocker_spaniel (0.01)
#   3: tennis_ball (0.01)
#   4: Brittany_spaniel (0.01)
#   5: Tibetan_terrier (0.00)
# Image 298:
#   1: vizsla (0.63)
#   2: Rhodesian_ridgeback (0.12)
#   3: bloodhound (0.09)
#   4: redbone (0.07)
#   5: Chesapeake_Bay_retriever (0.02)
# Image 299:
#   1: basenji (0.24)
#   2: Ibizan_hound (0.09)
#   3: Chihuahua (0.07)
#   4: Saint_Bernard (0.06)
#   5: Staffordshire_bullterrier (0.02)
# Image 300:
#   1: golden_retriever (0.97)
#   2: Labrador_retriever (0.01)
#   3: Saluki (0.00)
#   4: cocker_spaniel (0.00)
#   5: English_setter (0.00)
# Image 301:
#   1: African_hunting_dog (0.98)
#   2: dhole (0.01)
#   3: hyena (0.00)
#   4: bulletproof_vest (0.00)
#   5: hog (0.00)
# Image 302:
#   1: pug (0.67)
#   2: Brabancon_griffon (0.04)
#   3: bull_mastiff (0.02)
#   4: Norwegian_elkhound (0.01)
#   5: Pekinese (0.00)
# Image 303:
#   1: Weimaraner (0.64)
#   2: Italian_greyhound (0.05)
#   3: vizsla (0.02)
#   4: German_short-haired_pointer (0.01)
#   5: Ibizan_hound (0.01)
# Image 304:
#   1: affenpinscher (0.91)
#   2: Brabancon_griffon (0.03)
#   3: standard_schnauzer (0.00)
#   4: giant_schnauzer (0.00)
#   5: Tibetan_terrier (0.00)
# Image 305:
#   1: timber_wolf (0.81)
#   2: red_wolf (0.06)
#   3: dingo (0.02)
#   4: malamute (0.01)
#   5: white_wolf (0.01)
# Image 306:
#   1: red_wolf (0.66)
#   2: timber_wolf (0.15)
#   3: coyote (0.13)
#   4: grey_fox (0.01)
#   5: Norwegian_elkhound (0.01)
# Image 307:
#   1: Labrador_retriever (0.83)
#   2: Staffordshire_bullterrier (0.03)
#   3: American_Staffordshire_terrier (0.01)
#   4: golden_retriever (0.01)
#   5: Lakeland_terrier (0.00)
# Image 308:
#   1: golden_retriever (0.95)
#   2: tennis_ball (0.00)
#   3: clumber (0.00)
#   4: Labrador_retriever (0.00)
#   5: English_setter (0.00)
# Image 309:
#   1: Eskimo_dog (0.50)
#   2: Siberian_husky (0.35)
#   3: malamute (0.01)
#   4: seat_belt (0.00)
#   5: Norwegian_elkhound (0.00)
# Image 310:
#   1: Italian_greyhound (0.29)
#   2: basenji (0.11)
#   3: English_foxhound (0.06)
#   4: whippet (0.05)
#   5: American_Staffordshire_terrier (0.04)
# Image 311:
#   1: Irish_setter (0.21)
#   2: Rhodesian_ridgeback (0.11)
#   3: kelpie (0.07)
#   4: Doberman (0.06)
#   5: Appenzeller (0.05)
# Image 312:
#   1: Cardigan (0.17)
#   2: Pembroke (0.15)
#   3: English_foxhound (0.06)
#   4: beagle (0.04)
#   5: tennis_ball (0.04)
# Image 313:
#   1: English_foxhound (0.23)
#   2: Rhodesian_ridgeback (0.03)
#   3: German_short-haired_pointer (0.02)
#   4: boxer (0.02)
#   5: redbone (0.02)
# Image 314:
#   1: Walker_hound (0.70)
#   2: English_foxhound (0.11)
#   3: beagle (0.08)
#   4: basset (0.03)
#   5: bluetick (0.02)
# Image 315:
#   1: Sussex_spaniel (0.04)
#   2: menu (0.03)
#   3: bloodhound (0.03)
#   4: slot (0.01)
#   5: wall_clock (0.01)
# Image 316:
#   1: Blenheim_spaniel (0.75)
#   2: cocker_spaniel (0.10)
#   3: Welsh_springer_spaniel (0.01)
#   4: Sussex_spaniel (0.01)
#   5: Japanese_spaniel (0.00)
# Image 317:
#   1: dalmatian (0.85)
#   2: English_setter (0.02)
#   3: Labrador_retriever (0.01)
#   4: kuvasz (0.00)
#   5: muzzle (0.00)
# Image 318:
#   1: Pomeranian (0.73)
#   2: chow (0.03)
#   3: Japanese_spaniel (0.01)
#   4: keeshond (0.01)
#   5: Persian_cat (0.01)
# Image 319:
#   1: collie (0.96)
#   2: Shetland_sheepdog (0.01)
#   3: Border_collie (0.01)
#   4: Saint_Bernard (0.00)
#   5: borzoi (0.00)
# Image 320:
#   1: chow (0.86)
#   2: lion (0.01)
#   3: keeshond (0.00)
#   4: Tibetan_mastiff (0.00)
#   5: Tibetan_terrier (0.00)
# Image 321:
#   1: Weimaraner (0.58)
#   2: Great_Dane (0.31)
#   3: German_short-haired_pointer (0.02)
#   4: Doberman (0.01)
#   5: black-and-tan_coonhound (0.01)
# Image 322:
#   1: Great_Pyrenees (0.27)
#   2: Labrador_retriever (0.26)
#   3: kuvasz (0.21)
#   4: English_setter (0.07)
#   5: golden_retriever (0.02)
# Image 323:
#   1: Labrador_retriever (0.78)
#   2: American_Staffordshire_terrier (0.10)
#   3: Staffordshire_bullterrier (0.02)
#   4: dalmatian (0.01)
#   5: kuvasz (0.01)
# Image 324:
#   1: golden_retriever (0.40)
#   2: Pembroke (0.13)
#   3: collie (0.09)
#   4: Border_collie (0.02)
#   5: tennis_ball (0.02)
# Image 325:
#   1: Sussex_spaniel (0.77)
#   2: English_springer (0.05)
#   3: clumber (0.05)
#   4: cocker_spaniel (0.02)
#   5: Irish_water_spaniel (0.01)
# Image 326:
#   1: Walker_hound (0.31)
#   2: English_foxhound (0.12)
#   3: beagle (0.07)
#   4: bluetick (0.03)
#   5: Rhodesian_ridgeback (0.01)
# Image 327:
#   1: toy_poodle (0.51)
#   2: miniature_poodle (0.39)
#   3: teddy (0.01)
#   4: standard_poodle (0.01)
#   5: Airedale (0.00)
# Image 328:
#   1: swimming_trunks (0.34)
#   2: shower_curtain (0.14)
#   3: titi (0.04)
#   4: jellyfish (0.04)
#   5: comic_book (0.03)
# Image 329:
#   1: redbone (0.50)
#   2: vizsla (0.31)
#   3: bloodhound (0.04)
#   4: Rhodesian_ridgeback (0.04)
#   5: golden_retriever (0.01)
# Image 330:
#   1: web_site (0.45)
#   2: packet (0.05)
#   3: envelope (0.02)
#   4: comic_book (0.01)
#   5: Band_Aid (0.01)
# Image 331:
#   1: Irish_setter (0.35)
#   2: golden_retriever (0.10)
#   3: cocker_spaniel (0.02)
#   4: redbone (0.02)
#   5: bloodhound (0.02)
# Image 332:
#   1: pug (0.75)
#   2: bull_mastiff (0.07)
#   3: Brabancon_griffon (0.03)
#   4: tennis_ball (0.01)
#   5: golf_ball (0.00)
# Image 333:
#   1: pug (0.70)
#   2: Brabancon_griffon (0.06)
#   3: bull_mastiff (0.01)
#   4: Norwegian_elkhound (0.01)
#   5: chow (0.01)
# Image 334:
#   1: papillon (0.61)
#   2: Chihuahua (0.24)
#   3: Pomeranian (0.03)
#   4: Border_collie (0.02)
#   5: Pembroke (0.01)
# Image 335:
#   1: malinois (0.93)
#   2: Chihuahua (0.01)
#   3: African_hunting_dog (0.01)
#   4: dingo (0.00)
#   5: red_wolf (0.00)
# Image 336:
#   1: impala (0.07)
#   2: goose (0.06)
#   3: gazelle (0.04)
#   4: switch (0.04)
#   5: bustard (0.04)
# Image 337:
#   1: flat-coated_retriever (0.83)
#   2: Labrador_retriever (0.04)
#   3: curly-coated_retriever (0.02)
#   4: Sussex_spaniel (0.02)
#   5: Newfoundland (0.01)
# Image 338:
#   1: Labrador_retriever (0.39)
#   2: Weimaraner (0.15)
#   3: Great_Dane (0.10)
#   4: Chesapeake_Bay_retriever (0.10)
#   5: curly-coated_retriever (0.06)
# Image 339:
#   1: sarong (0.16)
#   2: kimono (0.08)
#   3: bearskin (0.07)
#   4: academic_gown (0.06)
#   5: abaya (0.05)
# Image 340:
#   1: Samoyed (0.27)
#   2: Pomeranian (0.21)
#   3: Japanese_spaniel (0.07)
#   4: Pekinese (0.06)
#   5: Arctic_fox (0.04)
# Image 341:
#   1: Leonberg (0.30)
#   2: Bouvier_des_Flandres (0.30)
#   3: briard (0.03)
#   4: Tibetan_mastiff (0.02)
#   5: Newfoundland (0.01)
# Image 342:
#   1: Yorkshire_terrier (0.81)
#   2: Norfolk_terrier (0.06)
#   3: silky_terrier (0.01)
#   4: soft-coated_wheaten_terrier (0.01)
#   5: Norwich_terrier (0.01)
# Image 343:
#   1: beagle (0.29)
#   2: Walker_hound (0.14)
#   3: English_foxhound (0.09)
#   4: basset (0.06)
#   5: Weimaraner (0.04)
# Image 344:
#   1: English_foxhound (0.46)
#   2: beagle (0.24)
#   3: Walker_hound (0.18)
#   4: Brittany_spaniel (0.02)
#   5: Welsh_springer_spaniel (0.00)
# Image 345:
#   1: Bernese_mountain_dog (0.34)
#   2: Appenzeller (0.21)
#   3: EntleBucher (0.12)
#   4: Greater_Swiss_Mountain_dog (0.05)
#   5: Border_collie (0.03)
# Image 346:
#   1: Afghan_hound (1.00)
#   2: briard (0.00)
#   3: Saluki (0.00)
#   4: Tibetan_terrier (0.00)
#   5: hartebeest (0.00)
# Image 347:
#   1: golden_retriever (0.92)
#   2: Labrador_retriever (0.03)
#   3: clumber (0.00)
#   4: cocker_spaniel (0.00)
#   5: otterhound (0.00)
# Image 348:
#   1: Italian_greyhound (0.12)
#   2: basenji (0.11)
#   3: American_Staffordshire_terrier (0.11)
#   4: Staffordshire_bullterrier (0.07)
#   5: Rhodesian_ridgeback (0.07)
# Image 349:
#   1: Labrador_retriever (0.45)
#   2: American_Staffordshire_terrier (0.20)
#   3: Staffordshire_bullterrier (0.11)
#   4: Chihuahua (0.08)
#   5: dingo (0.03)
# Image 350:
#   1: Border_terrier (0.60)
#   2: Chihuahua (0.05)
#   3: Dandie_Dinmont (0.02)
#   4: Labrador_retriever (0.02)
#   5: Lakeland_terrier (0.01)
# Image 351:
#   1: toy_terrier (0.53)
#   2: papillon (0.19)
#   3: Yorkshire_terrier (0.05)
#   4: Chihuahua (0.02)
#   5: Australian_terrier (0.01)
# Image 352:
#   1: Labrador_retriever (0.36)
#   2: golden_retriever (0.08)
#   3: dingo (0.04)
#   4: kelpie (0.02)
#   5: basenji (0.02)
# Image 353:
#   1: African_hunting_dog (0.78)
#   2: dhole (0.06)
#   3: hyena (0.02)
#   4: wallaby (0.01)
#   5: red_wolf (0.01)
# Image 354:
#   1: silky_terrier (0.56)
#   2: Yorkshire_terrier (0.13)
#   3: Australian_terrier (0.06)
#   4: mixing_bowl (0.01)
#   5: Sussex_spaniel (0.01)
# Image 355:
#   1: Pembroke (0.88)
#   2: Cardigan (0.05)
#   3: Chihuahua (0.01)
#   4: dingo (0.00)
#   5: German_shepherd (0.00)
# Image 356:
#   1: redbone (0.54)
#   2: Rhodesian_ridgeback (0.36)
#   3: black-and-tan_coonhound (0.03)
#   4: Walker_hound (0.01)
#   5: English_foxhound (0.01)
# Image 357:
#   1: plate_rack (0.03)
#   2: birdhouse (0.02)
#   3: binder (0.02)
#   4: comic_book (0.02)
#   5: pillow (0.02)
# Image 358:
#   1: Great_Pyrenees (0.37)
#   2: golden_retriever (0.25)
#   3: clumber (0.16)
#   4: English_setter (0.06)
#   5: kuvasz (0.02)
# Image 359:
#   1: American_Staffordshire_terrier (0.89)
#   2: Staffordshire_bullterrier (0.02)
#   3: Boston_bull (0.00)
#   4: Italian_greyhound (0.00)
#   5: Great_Dane (0.00)
# Image 360:
#   1: Ibizan_hound (0.42)
#   2: Cardigan (0.29)
#   3: basenji (0.07)
#   4: whippet (0.02)
#   5: Pembroke (0.01)
# Image 361:
#   1: Pembroke (0.89)
#   2: Cardigan (0.02)
#   3: papillon (0.01)
#   4: red_fox (0.01)
#   5: Chihuahua (0.00)
# Image 362:
#   1: basenji (0.97)
#   2: Staffordshire_bullterrier (0.00)
#   3: Rhodesian_ridgeback (0.00)
#   4: boxer (0.00)
#   5: American_Staffordshire_terrier (0.00)
# Image 363:
#   1: golden_retriever (0.30)
#   2: redbone (0.15)
#   3: Saluki (0.11)
#   4: English_foxhound (0.02)
#   5: Walker_hound (0.02)
# Image 364:
#   1: Tibetan_mastiff (0.75)
#   2: Bernese_mountain_dog (0.07)
#   3: Greater_Swiss_Mountain_dog (0.02)
#   4: Appenzeller (0.01)
#   5: EntleBucher (0.01)
# Image 365:
#   1: Great_Dane (0.24)
#   2: bull_mastiff (0.10)
#   3: American_Staffordshire_terrier (0.08)
#   4: boxer (0.06)
#   5: French_bulldog (0.03)
# Image 366:
#   1: Siberian_husky (0.25)
#   2: chow (0.18)
#   3: dingo (0.11)
#   4: Eskimo_dog (0.05)
#   5: dhole (0.04)
# Image 367:
#   1: golden_retriever (0.54)
#   2: tennis_ball (0.04)
#   3: Irish_setter (0.03)
#   4: Pembroke (0.02)
#   5: toy_terrier (0.01)
# Image 368:
#   1: neck_brace (0.09)
#   2: screw (0.07)
#   3: jigsaw_puzzle (0.05)
#   4: magpie (0.05)
#   5: nipple (0.03)
# Image 369:
#   1: Tibetan_mastiff (0.67)
#   2: chow (0.02)
#   3: Saint_Bernard (0.02)
#   4: Leonberg (0.01)
#   5: lion (0.01)
# Image 370:
#   1: beagle (0.17)
#   2: dingo (0.14)
#   3: Labrador_retriever (0.11)
#   4: redbone (0.07)
#   5: Rhodesian_ridgeback (0.07)
# Image 371:
#   1: Bernese_mountain_dog (0.55)
#   2: Appenzeller (0.16)
#   3: EntleBucher (0.10)
#   4: Greater_Swiss_Mountain_dog (0.09)
#   5: Gordon_setter (0.00)
# Image 372:
#   1: pug (0.95)
#   2: bull_mastiff (0.03)
#   3: French_bulldog (0.00)
#   4: Brabancon_griffon (0.00)
#   5: Pekinese (0.00)
# Image 373:
#   1: bloodhound (0.27)
#   2: abaya (0.05)
#   3: golden_retriever (0.04)
#   4: sarong (0.03)
#   5: Rhodesian_ridgeback (0.02)
# Image 374:
#   1: vizsla (0.41)
#   2: German_short-haired_pointer (0.15)
#   3: Rhodesian_ridgeback (0.04)
#   4: Labrador_retriever (0.03)
#   5: Sussex_spaniel (0.02)
# Image 375:
#   1: standard_poodle (0.44)
#   2: miniature_poodle (0.36)
#   3: toy_poodle (0.12)
#   4: Bedlington_terrier (0.00)
#   5: Dandie_Dinmont (0.00)
# Image 376:
#   1: Labrador_retriever (0.69)
#   2: bull_mastiff (0.03)
#   3: bloodhound (0.01)
#   4: Rhodesian_ridgeback (0.01)
#   5: Saint_Bernard (0.01)
# Image 377:
#   1: Irish_terrier (0.82)
#   2: Airedale (0.04)
#   3: wire-haired_fox_terrier (0.03)
#   4: Lakeland_terrier (0.01)
#   5: Rhodesian_ridgeback (0.01)
# Image 378:
#   1: Labrador_retriever (0.88)
#   2: golden_retriever (0.06)
#   3: beagle (0.00)
#   4: tennis_ball (0.00)
#   5: Chesapeake_Bay_retriever (0.00)
# Image 379:
#   1: golden_retriever (0.79)
#   2: Labrador_retriever (0.03)
#   3: Great_Pyrenees (0.02)
#   4: kuvasz (0.01)
#   5: collie (0.01)
# Image 380:
#   1: German_short-haired_pointer (0.25)
#   2: Brittany_spaniel (0.11)
#   3: English_foxhound (0.08)
#   4: Walker_hound (0.06)
#   5: bluetick (0.05)
# Image 381:
#   1: Pomeranian (0.51)
#   2: muzzle (0.24)
#   3: Chihuahua (0.09)
#   4: Pekinese (0.02)
#   5: papillon (0.01)
# Image 382:
#   1: Norfolk_terrier (0.25)
#   2: otterhound (0.22)
#   3: Irish_terrier (0.14)
#   4: Australian_terrier (0.06)
#   5: briard (0.03)
# Image 383:
#   1: Weimaraner (0.94)
#   2: Chesapeake_Bay_retriever (0.01)
#   3: German_short-haired_pointer (0.00)
#   4: vizsla (0.00)
#   5: Labrador_retriever (0.00)
# Image 384:
#   1: Rhodesian_ridgeback (0.22)
#   2: Ibizan_hound (0.14)
#   3: redbone (0.12)
#   4: vizsla (0.04)
#   5: malinois (0.04)
# Image 385:
#   1: pug (0.93)
#   2: Brabancon_griffon (0.01)
#   3: bull_mastiff (0.00)
#   4: Pekinese (0.00)
#   5: French_bulldog (0.00)
# Image 386:
#   1: briard (0.15)
#   2: Sussex_spaniel (0.09)
#   3: Afghan_hound (0.02)
#   4: curly-coated_retriever (0.02)
#   5: otterhound (0.02)
# Image 387:
#   1: Chihuahua (0.43)
#   2: toy_terrier (0.13)
#   3: Pembroke (0.05)
#   4: Cardigan (0.01)
#   5: French_bulldog (0.01)
# Image 388:
#   1: Lhasa (0.24)
# ...
#   1: Doberman (0.14)
#   2: sea_lion (0.06)
#   3: platypus (0.04)
#   4: flat-coated_retriever (0.03)
#   5: English_setter (0.02)
# Image 443:
#   1: Doberman (0.72)
#   2: hartebeest (0.03)
#   3: Gordon_setter (0.01)
#   4: black-and-tan_coonhound (0.01)
#   5: miniature_pinscher (0.01)
# Image 444:
#   1: Labrador_retriever (0.23)
#   2: English_foxhound (0.08)
#   3: whippet (0.07)
#   4: bull_mastiff (0.05)
#   5: Rhodesian_ridgeback (0.04)
# Image 445:
#   1: Blenheim_spaniel (0.89)
#   2: Saint_Bernard (0.01)
#   3: Pekinese (0.01)
#   4: cocker_spaniel (0.00)
#   5: Japanese_spaniel (0.00)
# Image 446:
#   1: weasel (0.16)
#   2: bath_towel (0.15)
#   3: shower_curtain (0.06)
#   4: toy_terrier (0.03)
#   5: Siamese_cat (0.02)
# Image 447:
#   1: Border_collie (0.25)
#   2: collie (0.15)
#   3: Shetland_sheepdog (0.12)
#   4: Bernese_mountain_dog (0.08)
#   5: Appenzeller (0.03)
# Image 448:
#   1: cocker_spaniel (0.28)
#   2: Sussex_spaniel (0.21)
#   3: clumber (0.03)
#   4: Irish_setter (0.02)
#   5: Welsh_springer_spaniel (0.01)
# Image 449:
#   1: flat-coated_retriever (0.42)
#   2: Labrador_retriever (0.20)
#   3: German_short-haired_pointer (0.04)
#   4: whippet (0.03)
#   5: bluetick (0.01)
# Image 450:
#   1: German_shepherd (0.83)
#   2: malinois (0.09)
#   3: Norwegian_elkhound (0.02)
#   4: Great_Dane (0.00)
#   5: Leonberg (0.00)
# Image 451:
#   1: English_springer (0.22)
#   2: Brittany_spaniel (0.12)
#   3: Welsh_springer_spaniel (0.11)
#   4: Japanese_spaniel (0.07)
#   5: Blenheim_spaniel (0.05)
# Image 452:
#   1: sandbar (0.23)
#   2: snorkel (0.07)
#   3: seashore (0.06)
#   4: shovel (0.02)
#   5: sunscreen (0.02)
# Image 453:
#   1: Blenheim_spaniel (0.80)
#   2: Shih-Tzu (0.04)
#   3: cocker_spaniel (0.02)
#   4: English_springer (0.01)
#   5: basset (0.01)
# Image 454:
#   1: pug (0.76)
#   2: bull_mastiff (0.13)
#   3: Brabancon_griffon (0.01)
#   4: French_bulldog (0.00)
#   5: muzzle (0.00)
# Image 455:
#   1: Brittany_spaniel (0.52)
#   2: Border_collie (0.10)
#   3: collie (0.05)
#   4: borzoi (0.03)
#   5: Ibizan_hound (0.02)
# Image 456:
#   1: Border_collie (0.57)
#   2: collie (0.39)
#   3: Bernese_mountain_dog (0.00)
#   4: sloth_bear (0.00)
#   5: groenendael (0.00)
# Image 457:
#   1: Great_Dane (0.42)
#   2: Doberman (0.13)
#   3: whippet (0.10)
#   4: Weimaraner (0.03)
#   5: Italian_greyhound (0.03)
# Image 458:
#   1: Pomeranian (0.82)
#   2: chow (0.04)
#   3: toy_poodle (0.01)
#   4: teddy (0.00)
#   5: Pembroke (0.00)
# Image 459:
#   1: Bernese_mountain_dog (0.80)
#   2: EntleBucher (0.06)
#   3: Appenzeller (0.04)
#   4: Greater_Swiss_Mountain_dog (0.03)
#   5: Saint_Bernard (0.00)
# Image 460:
#   1: Doberman (0.54)
#   2: muzzle (0.05)
#   3: whippet (0.04)
#   4: Rottweiler (0.03)
#   5: Saluki (0.02)
# Image 461:
#   1: dingo (0.47)
#   2: kelpie (0.21)
#   3: basenji (0.04)
#   4: Staffordshire_bullterrier (0.04)
#   5: American_Staffordshire_terrier (0.04)
# Image 462:
#   1: diaper (0.19)
#   2: wallet (0.04)
#   3: jigsaw_puzzle (0.04)
#   4: bow_tie (0.04)
#   5: pick (0.03)
# Image 463:
#   1: German_shepherd (0.98)
#   2: malinois (0.00)
#   3: kelpie (0.00)
#   4: dingo (0.00)
#   5: Norwegian_elkhound (0.00)
# Image 464:
#   1: American_Staffordshire_terrier (0.70)
#   2: Staffordshire_bullterrier (0.18)
#   3: Rhodesian_ridgeback (0.05)
#   4: basenji (0.01)
#   5: dingo (0.01)
# Image 465:
#   1: miniature_poodle (0.95)
#   2: toy_poodle (0.03)
#   3: standard_poodle (0.00)
#   4: Bedlington_terrier (0.00)
#   5: soft-coated_wheaten_terrier (0.00)
# Image 466:
#   1: Bernese_mountain_dog (0.81)
#   2: EntleBucher (0.04)
#   3: Appenzeller (0.03)
#   4: Greater_Swiss_Mountain_dog (0.02)
#   5: Saint_Bernard (0.00)
# Image 467:
#   1: Eskimo_dog (0.30)
#   2: malamute (0.20)
#   3: Siberian_husky (0.13)
#   4: timber_wolf (0.07)
#   5: Norwegian_elkhound (0.04)
# Image 468:
#   1: Weimaraner (0.83)
#   2: Great_Dane (0.01)
#   3: vizsla (0.00)
#   4: German_short-haired_pointer (0.00)
#   5: Doberman (0.00)
# Image 469:
#   1: Irish_terrier (0.33)
#   2: wire-haired_fox_terrier (0.21)
#   3: Norfolk_terrier (0.04)
#   4: Lakeland_terrier (0.03)
#   5: Border_terrier (0.02)
# Image 470:
#   1: pug (0.78)
#   2: boxer (0.02)
#   3: Boston_bull (0.01)
#   4: Brabancon_griffon (0.01)
#   5: bull_mastiff (0.01)
# Image 471:
#   1: Sussex_spaniel (0.08)
#   2: cocker_spaniel (0.06)
#   3: German_short-haired_pointer (0.03)
#   4: muzzle (0.01)
#   5: clumber (0.01)
# Image 472:
#   1: Cardigan (0.51)
#   2: kelpie (0.21)
#   3: Border_collie (0.16)
#   4: basenji (0.01)
#   5: Ibizan_hound (0.01)
# Image 473:
#   1: Border_collie (0.85)
#   2: collie (0.08)
#   3: Welsh_springer_spaniel (0.01)
#   4: Brittany_spaniel (0.01)
#   5: Shetland_sheepdog (0.00)
# Image 474:
#   1: Pomeranian (0.94)
#   2: papillon (0.01)
#   3: Chihuahua (0.00)
#   4: keeshond (0.00)
#   5: Japanese_spaniel (0.00)
# Image 475:
#   1: dingo (0.32)
#   2: chow (0.09)
#   3: Eskimo_dog (0.05)
#   4: golden_retriever (0.03)
#   5: Pembroke (0.03)
# Image 476:
#   1: Samoyed (0.87)
#   2: Arctic_fox (0.01)
#   3: Maltese_dog (0.00)
#   4: white_wolf (0.00)
#   5: chow (0.00)
# Image 477:
#   1: Walker_hound (0.27)
#   2: Ibizan_hound (0.15)
#   3: Cardigan (0.05)
#   4: basenji (0.04)
#   5: English_foxhound (0.04)
# Image 478:
#   1: Labrador_retriever (0.50)
#   2: English_foxhound (0.10)
#   3: Walker_hound (0.09)
#   4: Rhodesian_ridgeback (0.03)
#   5: redbone (0.01)
# Image 479:
#   1: Samoyed (0.93)
#   2: Pomeranian (0.01)
#   3: white_wolf (0.00)
#   4: Arctic_fox (0.00)
#   5: Great_Pyrenees (0.00)
# Image 480:
#   1: papillon (0.40)
#   2: wire-haired_fox_terrier (0.10)
#   3: Sealyham_terrier (0.05)
#   4: Border_collie (0.02)
#   5: West_Highland_white_terrier (0.01)
# Image 481:
#   1: Saluki (0.07)
#   2: muzzle (0.05)
#   3: whippet (0.04)
#   4: malinois (0.03)
#   5: boxer (0.03)
# Image 482:
#   1: Bernese_mountain_dog (0.64)
#   2: Appenzeller (0.05)
#   3: EntleBucher (0.04)
#   4: Greater_Swiss_Mountain_dog (0.02)
#   5: Tibetan_terrier (0.01)
# Image 483:
#   1: West_Highland_white_terrier (0.87)
#   2: Maltese_dog (0.10)
#   3: Old_English_sheepdog (0.01)
#   4: Lhasa (0.00)
#   5: Norfolk_terrier (0.00)
# Image 484:
#   1: Tibetan_terrier (0.41)
#   2: otterhound (0.26)
#   3: Sussex_spaniel (0.04)
#   4: cocker_spaniel (0.03)
#   5: Norfolk_terrier (0.02)
# Image 485:
#   1: golden_retriever (0.58)
#   2: Saluki (0.19)
#   3: Great_Pyrenees (0.02)
#   4: kuvasz (0.01)
#   5: Labrador_retriever (0.01)
# Image 486:
#   1: Saint_Bernard (0.29)
#   2: Cardigan (0.10)
#   3: French_bulldog (0.05)
#   4: Siamese_cat (0.04)
#   5: muzzle (0.03)
# Image 487:
#   1: Pembroke (0.69)
#   2: Cardigan (0.10)
#   3: Eskimo_dog (0.04)
#   4: German_shepherd (0.03)
#   5: Siberian_husky (0.01)
# Image 488:
#   1: Labrador_retriever (0.28)
#   2: golden_retriever (0.28)
#   3: beagle (0.18)
#   4: Norfolk_terrier (0.04)
#   5: Rhodesian_ridgeback (0.04)
# Image 489:
#   1: Norfolk_terrier (0.60)
#   2: Tibetan_terrier (0.16)
#   3: Lhasa (0.03)
#   4: soft-coated_wheaten_terrier (0.02)
#   5: Irish_terrier (0.02)
# Image 490:
#   1: Rhodesian_ridgeback (0.23)
#   2: Irish_setter (0.10)
#   3: vizsla (0.05)
#   4: Labrador_retriever (0.05)
#   5: bull_mastiff (0.04)
# Image 491:
#   1: Labrador_retriever (0.81)
#   2: English_foxhound (0.05)
#   3: Great_Dane (0.02)
#   4: beagle (0.02)
#   5: Rhodesian_ridgeback (0.01)
# Image 492:
#   1: Shih-Tzu (0.40)
#   2: Lhasa (0.06)
#   3: Pekinese (0.06)
#   4: Tibetan_terrier (0.05)
#   5: Japanese_spaniel (0.03)
# Image 493:
#   1: English_springer (0.12)
#   2: cocker_spaniel (0.11)
#   3: bluetick (0.07)
#   4: Chihuahua (0.07)
#   5: Boston_bull (0.05)
# Image 494:
#   1: EntleBucher (0.17)
#   2: toy_terrier (0.15)
#   3: weasel (0.05)
#   4: Chihuahua (0.04)
#   5: black-and-tan_coonhound (0.03)
# Image 495:
#   1: golden_retriever (0.91)
#   2: Leonberg (0.01)
#   3: Labrador_retriever (0.01)
#   4: Rhodesian_ridgeback (0.01)
#   5: tennis_ball (0.00)
# Image 496:
#   1: Lhasa (0.19)
#   2: Yorkshire_terrier (0.13)
#   3: Shih-Tzu (0.10)
#   4: silky_terrier (0.03)
#   5: Maltese_dog (0.02)
# Image 497:
#   1: golden_retriever (0.91)
#   2: Labrador_retriever (0.03)
#   3: clumber (0.01)
#   4: kuvasz (0.01)
#   5: Brittany_spaniel (0.00)
# Image 498:
#   1: Italian_greyhound (0.30)
#   2: whippet (0.17)
#   3: miniature_schnauzer (0.04)
#   4: Saluki (0.03)
#   5: Great_Dane (0.02)
# Image 499:
#   1: dalmatian (0.41)
#   2: Eskimo_dog (0.11)
#   3: Siberian_husky (0.11)
#   4: malamute (0.04)
#   5: Great_Dane (0.01)
# Image 500:
#   1: briard (0.27)
#   2: otterhound (0.11)
#   3: Bouvier_des_Flandres (0.07)
#   4: hamper (0.04)
#   5: Scottish_deerhound (0.02)
# Image 501:
#   1: Newfoundland (0.46)
#   2: Tibetan_mastiff (0.20)
#   3: Bernese_mountain_dog (0.04)
#   4: Bouvier_des_Flandres (0.04)
#   5: briard (0.03)
# Image 502:
#   1: Italian_greyhound (0.25)
#   2: Ibizan_hound (0.17)
#   3: Saluki (0.07)
#   4: vizsla (0.04)
#   5: Chihuahua (0.03)
# Image 503:
#   1: bluetick (0.43)
#   2: kelpie (0.09)
#   3: toy_terrier (0.03)
#   4: Australian_terrier (0.03)
#   5: silky_terrier (0.02)
# Image 504:
#   1: Brittany_spaniel (0.49)
#   2: English_springer (0.33)
#   3: German_short-haired_pointer (0.04)
#   4: Walker_hound (0.01)
#   5: Border_collie (0.01)
# Image 505:
#   1: Sussex_spaniel (0.37)
#   2: Irish_setter (0.05)
#   3: flat-coated_retriever (0.03)
#   4: beer_glass (0.02)
#   5: cocker_spaniel (0.01)
# Image 506:
#   1: Brittany_spaniel (0.61)
#   2: English_foxhound (0.12)
#   3: Welsh_springer_spaniel (0.09)
#   4: Ibizan_hound (0.04)
#   5: wire-haired_fox_terrier (0.02)
# Image 507:
#   1: German_shepherd (0.71)
#   2: malinois (0.22)
#   3: African_hunting_dog (0.01)
#   4: dingo (0.00)
#   5: red_wolf (0.00)
# Image 508:
#   1: mask (0.09)
#   2: maillot (0.08)
#   3: backpack (0.03)
#   4: jersey (0.03)
#   5: pinwheel (0.02)
# Image 509:
#   1: dingo (0.34)
#   2: Irish_terrier (0.06)
#   3: redbone (0.05)
#   4: dhole (0.04)
#   5: malinois (0.02)
# Image 510:
#   1: Lhasa (0.51)
#   2: Dandie_Dinmont (0.14)
#   3: Tibetan_terrier (0.06)
#   4: otterhound (0.04)
#   5: Shih-Tzu (0.04)
# Image 511:
#   1: Border_collie (0.82)
#   2: collie (0.10)
#   3: papillon (0.01)
#   4: tennis_ball (0.01)
#   5: Japanese_spaniel (0.00)
# Image 512:
#   1: Labrador_retriever (0.71)
#   2: Great_Dane (0.08)
#   3: Rottweiler (0.04)
#   4: Staffordshire_bullterrier (0.02)
#   5: black-and-tan_coonhound (0.02)
# Image 513:
#   1: dalmatian (0.25)
#   2: German_short-haired_pointer (0.18)
#   3: Great_Dane (0.12)
#   4: whippet (0.06)
#   5: English_springer (0.05)
# Image 514:
#   1: papillon (0.47)
#   2: Japanese_spaniel (0.20)
#   3: Pekinese (0.09)
#   4: Sealyham_terrier (0.01)
#   5: Tibetan_terrier (0.01)
# Image 515:
#   1: kelpie (0.14)
#   2: tennis_ball (0.10)
#   3: Rottweiler (0.04)
#   4: German_shepherd (0.04)
#   5: golden_retriever (0.03)
# Image 516:
#   1: wall_clock (0.43)
#   2: toyshop (0.08)
#   3: nipple (0.06)
#   4: ocarina (0.03)
#   5: magnetic_compass (0.03)
# Image 517:
#   1: Maltese_dog (0.95)
#   2: Lhasa (0.01)
#   3: Dandie_Dinmont (0.00)
#   4: Sealyham_terrier (0.00)
#   5: Shih-Tzu (0.00)
# Image 518:
#   1: Rhodesian_ridgeback (0.36)
#   2: Great_Dane (0.15)
#   3: American_Staffordshire_terrier (0.15)
#   4: bull_mastiff (0.03)
#   5: redbone (0.01)
# Image 519:
#   1: Eskimo_dog (0.16)
#   2: dingo (0.15)
#   3: German_shepherd (0.10)
#   4: Siberian_husky (0.07)
#   5: Norwegian_elkhound (0.07)
# Image 520:
#   1: Irish_setter (0.94)
#   2: golden_retriever (0.01)
#   3: Sussex_spaniel (0.01)
#   4: vizsla (0.00)
#   5: Saluki (0.00)
# Image 521:
#   1: chow (0.86)
#   2: Tibetan_terrier (0.01)
#   3: Tibetan_mastiff (0.00)
#   4: golden_retriever (0.00)
#   5: Newfoundland (0.00)
# Image 522:
#   1: Cardigan (0.25)
#   2: Pembroke (0.25)
#   3: Brittany_spaniel (0.04)
#   4: Appenzeller (0.03)
#   5: beagle (0.02)
# Image 523:
#   1: Great_Dane (0.74)
#   2: Doberman (0.03)
#   3: American_Staffordshire_terrier (0.02)
#   4: boxer (0.01)
#   5: Rhodesian_ridgeback (0.01)
# Image 524:
#   1: Labrador_retriever (0.17)
#   2: golden_retriever (0.13)
#   3: dingo (0.09)
#   4: Saluki (0.09)
#   5: kelpie (0.04)
# Image 525:
#   1: mouse (0.07)
#   2: Lhasa (0.07)
#   3: bloodhound (0.07)
#   4: Pekinese (0.03)
#   5: Shih-Tzu (0.03)
# Image 526:
#   1: Labrador_retriever (0.23)
#   2: redbone (0.13)
#   3: Saluki (0.12)
#   4: golden_retriever (0.05)
#   5: Rhodesian_ridgeback (0.02)
# Image 527:
#   1: Saluki (0.58)
#   2: Walker_hound (0.13)
#   3: whippet (0.06)
#   4: English_foxhound (0.05)
#   5: Italian_greyhound (0.02)
# Image 528:
#   1: Cardigan (0.59)
#   2: Pembroke (0.35)
#   3: basset (0.00)
#   4: beagle (0.00)
#   5: Welsh_springer_spaniel (0.00)
# Image 529:
#   1: Appenzeller (0.41)
#   2: EntleBucher (0.34)
#   3: Greater_Swiss_Mountain_dog (0.12)
#   4: Bernese_mountain_dog (0.03)
#   5: Border_collie (0.01)
# Image 530:
#   1: Eskimo_dog (0.58)
#   2: Siberian_husky (0.25)
#   3: malamute (0.04)
#   4: Border_collie (0.01)
#   5: Pembroke (0.00)
# Image 531:
#   1: Labrador_retriever (0.36)
#   2: Rottweiler (0.06)
#   3: Great_Dane (0.06)
#   4: bull_mastiff (0.04)
#   5: American_Staffordshire_terrier (0.03)
# Image 532:
#   1: cocker_spaniel (0.55)
#   2: clumber (0.24)
#   3: Sussex_spaniel (0.04)
#   4: bloodhound (0.01)
#   5: miniature_poodle (0.01)
# Image 533:
#   1: Staffordshire_bullterrier (0.40)
#   2: Labrador_retriever (0.15)
#   3: American_Staffordshire_terrier (0.05)
#   4: Newfoundland (0.04)
#   5: Rottweiler (0.03)
# Image 534:
#   1: basenji (0.97)
#   2: American_Staffordshire_terrier (0.00)
#   3: Mexican_hairless (0.00)
#   4: Staffordshire_bullterrier (0.00)
#   5: Appenzeller (0.00)
# Image 535:
#   1: boxer (0.68)
#   2: bull_mastiff (0.15)
#   3: pug (0.03)
#   4: French_bulldog (0.01)
#   5: Saint_Bernard (0.01)
# Image 536:
#   1: miniature_poodle (0.25)
#   2: toy_poodle (0.12)
#   3: standard_poodle (0.08)
#   4: Norwich_terrier (0.07)
#   5: Irish_terrier (0.05)
# Image 537:
#   1: dalmatian (0.12)
#   2: beagle (0.07)
#   3: Border_terrier (0.06)
#   4: cocker_spaniel (0.05)
#   5: English_setter (0.04)
# Image 538:
#   1: Tibetan_terrier (0.18)
#   2: miniature_schnauzer (0.08)
#   3: Scottish_deerhound (0.05)
#   4: Shih-Tzu (0.05)
#   5: muzzle (0.04)
# Image 539:
#   1: kelpie (0.72)
#   2: Ibizan_hound (0.09)
#   3: Brittany_spaniel (0.01)
#   4: German_short-haired_pointer (0.01)
#   5: Cardigan (0.01)
# Image 540:
#   1: boxer (0.69)
#   2: Saint_Bernard (0.06)
#   3: bull_mastiff (0.04)
#   4: English_foxhound (0.01)
#   5: American_Staffordshire_terrier (0.01)
# Image 541:
#   1: Border_collie (0.80)
#   2: borzoi (0.07)
#   3: collie (0.03)
#   4: Saluki (0.01)
#   5: Shetland_sheepdog (0.01)
# Image 542:
#   1: Chihuahua (0.91)
#   2: toy_terrier (0.01)
#   3: Pembroke (0.01)
#   4: Cardigan (0.00)
#   5: French_bulldog (0.00)
# Image 543:
#   1: miniature_schnauzer (0.28)
#   2: standard_schnauzer (0.05)
#   3: Shih-Tzu (0.03)
#   4: Italian_greyhound (0.03)
#   5: whippet (0.03)
# Image 544:
#   1: cocker_spaniel (0.54)
#   2: Sussex_spaniel (0.19)
#   3: Blenheim_spaniel (0.07)
#   4: Irish_setter (0.01)
#   5: clumber (0.01)
# Image 545:
#   1: Great_Dane (0.29)
#   2: malinois (0.23)
#   3: French_bulldog (0.11)
#   4: German_shepherd (0.03)
#   5: bull_mastiff (0.02)
# Image 546:
#   1: Bernese_mountain_dog (0.82)
#   2: Greater_Swiss_Mountain_dog (0.05)
#   3: Appenzeller (0.02)
#   4: EntleBucher (0.01)
#   5: Border_collie (0.00)
# Image 547:
#   1: toy_poodle (0.67)
#   2: miniature_poodle (0.21)
#   3: hamper (0.01)
#   4: swab (0.01)
#   5: ashcan (0.01)
# Image 548:
#   1: English_foxhound (0.36)
#   2: Walker_hound (0.13)
#   3: Labrador_retriever (0.11)
#   4: beagle (0.03)
#   5: Brittany_spaniel (0.02)
# Image 549:
#   1: golden_retriever (0.22)
#   2: borzoi (0.11)
#   3: Afghan_hound (0.03)
#   4: Saluki (0.03)
#   5: Irish_setter (0.03)
# Image 550:
#   1: Border_collie (0.59)
#   2: Bernese_mountain_dog (0.16)
#   3: collie (0.04)
#   4: Appenzeller (0.02)
#   5: EntleBucher (0.01)
# Image 551:
#   1: dalmatian (0.29)
#   2: toyshop (0.04)
#   3: ocarina (0.03)
#   4: comic_book (0.02)
#   5: teddy (0.02)
# Image 552:
#   1: German_shepherd (0.29)
#   2: malinois (0.10)
#   3: bull_mastiff (0.05)
#   4: kelpie (0.05)
#   5: Rhodesian_ridgeback (0.05)
# Image 553:
#   1: black-and-tan_coonhound (0.82)
#   2: bloodhound (0.02)
#   3: Gordon_setter (0.01)
#   4: Doberman (0.00)
#   5: redbone (0.00)
# Image 554:
#   1: EntleBucher (0.58)
#   2: Appenzeller (0.13)
#   3: Greater_Swiss_Mountain_dog (0.07)
#   4: Rottweiler (0.03)
#   5: Bernese_mountain_dog (0.02)
# Image 555:
#   1: toy_terrier (0.20)
#   2: English_foxhound (0.08)
#   3: wire-haired_fox_terrier (0.08)
#   4: basenji (0.03)
#   5: Staffordshire_bullterrier (0.03)
# Image 556:
#   1: beagle (0.94)
#   2: English_foxhound (0.02)
#   3: Walker_hound (0.02)
#   4: Labrador_retriever (0.00)
#   5: basset (0.00)
# Image 557:
#   1: Labrador_retriever (0.32)
#   2: Saluki (0.03)
#   3: English_foxhound (0.03)
#   4: kuvasz (0.02)
#   5: Walker_hound (0.02)

# %% [markdown]
# ###  The output only has two classes (cats and dogs), the ImageNet pre-trained model's original classification head (1000 classes) cannot directly evaluate or classify your data. So, we can fine-tune the pre-trained model.
